# %%
from __future__ import print_function
import numpy as np
import pandas as pd

from sklearn.ensemble  import RandomForestClassifier as rfc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
# the directory that contains all the files
dataDirectory = 'data/'

# %%
file = 'llcp2017_formatted.csv'
df = pd.read_csv(dataDirectory+file)
# Out:
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (3,170,174) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   STATE FIPS CODE FILE MONTH  INTERVIEW DATE INTERVIEW MONTH  INTERVIEW DAY  \
# 0         Alabama    January         1302017              01             30
# 1         Alabama    January         1122017              01             12
# 2         Alabama    January         1102017              01             10
# 3         Alabama    January         2082017              02              8
# 4         Alabama    January         1302017              01             30
#
#    INTERVIEW YEAR  FINAL DISPOSITION  ANNUAL SEQUENCE NUMBER  \
# 0            2017               1100              2017000001
# 1            2017               1100              2017000002
# 2            2017               1100              2017000003
# 3            2017               1200              2017000004
# 4            2017               1100              2017000005
#
#    PRIMARY SAMPLING UNIT CORRECT TELEPHONE NUMBER?   ...     \
# 0             2017000001                       Yes   ...
# 1             2017000002                       Yes   ...
# 2             2017000003                       Yes   ...
# 3             2017000004                       Yes   ...
# 4             2017000005                       Yes   ...
#
#                _IMPCAGE _IMPCRAC  _IMPCSEX _IMPEDUC  _IMPHOME  _IMPMRTL  \
# 0  Not asked or Missing  Missing   Missing  Missing   Missing   Missing
# 1  Not asked or Missing  Missing   Missing  Missing   Missing   Missing
# 2  Not asked or Missing  Missing   Missing  Missing   Missing   Missing
# 3  Not asked or Missing  Missing   Missing  Missing   Missing   Missing
# 4  Not asked or Missing  Missing   Missing  Missing   Missing   Missing
#
#    _IMPNPH               _IMPSEX               _M_RACE _URBNRRL
# 0      NaN  Not asked or Missing  Not asked or Missing  Missing
# 1      NaN  Not asked or Missing  Not asked or Missing  Missing
# 2      NaN  Not asked or Missing  Not asked or Missing  Missing
# 3      NaN  Not asked or Missing  Not asked or Missing  Missing
# 4      NaN  Not asked or Missing  Not asked or Missing  Missing
#
# [5 rows x 384 columns]

# %%
print("Number of records: ",len(df))
# Out:
# Number of records:  450642

# %%
df['INTERVIEW YEAR'].value_counts()/np.sum(df['INTERVIEW YEAR'].value_counts())
# Out:
# 2017    0.973964
# 2018    0.026036
# Name: INTERVIEW YEAR, dtype: float64

# %% [markdown]
# #### Most of the data is from 2017

# %%
list(np.sort(df.columns))
# Out:
# ['(EVER TOLD) YOU HAD ANY OTHER TYPES OF C',
#  '(EVER TOLD) YOU HAD SKIN CANCER?',
#  '(EVER TOLD) YOU HAVE (COPD) CHRONIC OBST',
#  '(EVER TOLD) YOU HAVE DIABETES',
#  '(EVER TOLD) YOU HAVE KIDNEY DISEASE?',
#  '150 MINUTE PHYSICAL ACTIVITY CALCULATED',
#  '300 MINUTE PHYSICAL ACTIVITY 2-LEVEL CAL',
#  '300 MINUTE PHYSICAL ACTIVITY CALCULATED',
#  'ACTIVITIES LIMITED DUE TO ASTHMA DURING',
#  'ACTIVITY MET VALUE FOR FIRST ACTIVITY',
#  'ACTIVITY MET VALUE FOR SECOND ACTIVITY',
#  'ADLTCHLD',
#  'ADULT FLU SHOT/SPRAY PAST 12 MOS',
#  'ADULTS WITH GOOD OR BETTER HEALTH',
#  'AEROBIC AND STRENGTHENING (2-LEVEL)',
#  'AEROBIC AND STRENGTHENING GUIDELINE',
#  'AGE',
#  'AGE AT ASTHMA DIAGNOSIS',
#  'AGE TOLD HAD CANCER',
#  'AGE WHEN TOLD DIABETIC',
#  'ALWAYS OR NEARLY ALWAYS WEAR SEAT BELTS',
#  'ALWAYS WEAR SEAT BELTS',
#  'ANNUAL SEQUENCE NUMBER',
#  'ANY FIREARMS IN HOME',
#  'ANY FIREARMS LOADED',
#  'ANY LOADED FIREARMS ALSO UNLOCKED',
#  'ARE YOU 18 YEARS OF AGE OR OLDER?',
#  'ARE YOU 18 YEARS OF AGE OR OLDER?.1',
#  'ARE YOU A VETERAN',
#  'ARE YOU DEAF OR DO YOU HAVE SERIOUS DIFF',
#  'ASKED DURING CHECKUP IF YOU DRINK ALCHOH',
#  'ASKED IN PERSON OR BY FORM HOW MUCH YOU',
#  'ASKED WHETHER YOU DRANK [5 FOR MEN /4 FO',
#  'ASTHMA DURING PAST 12 MONTHS',
#  'ASTHMA SYMPTOMS DURING PAST 30 DAYS',
#  'AVG ALCOHOLIC DRINKS PER DAY IN PAST 30',
#  'BINGE DRINKING',
#  'BINGE DRINKING CALCULATED VARIABLE',
#  'BLIND OR DIFFICULTY SEEING',
#  'CALCULATED NON-HISPANIC RACE INCLUDING M',
#  'CALLBACK',
#  'CALLBCKZ',
#  'CELLULAR TELEPHONE',
#  'CHANGE EATING HABITS FOR BP?',
#  'CHILD HISPANIC, LATINO/A, OR SPANISH ORI',
#  'CHILD NON-HISPANIC RACE INCLUDING MULTIR',
#  'CHILD STILL HAVE ASTHMA?',
#  'CHILDAGE',
#  'CHOLESTEROL CHECKED CALCULATED VARIABLE',
#  'COMPUTED ASTHMA STATUS',
#  'COMPUTED BODY MASS INDEX',
#  'COMPUTED BODY MASS INDEX CATEGORIES',
#  'COMPUTED DARK GREEN VEGETABLE INTAKE IN',
#  'COMPUTED DRINK-OCCASIONS-PER-DAY',
#  'COMPUTED E-CIGARETTE USER STATUS',
#  'COMPUTED FIVE LEVEL RACE/ETHNICITY CATEG',
#  'COMPUTED FRUIT INTAKE IN TIMES PER DAY',
#  'COMPUTED FRUIT JUICE INTAKE IN TIMES PER',
#  'COMPUTED HEIGHT IN INCHES',
#  'COMPUTED HEIGHT IN METERS',
#  'COMPUTED INCOME CATEGORIES',
#  'COMPUTED LEVEL OF EDUCATION COMPLETED CA',
#  'COMPUTED MENTAL HEALTH STATUS',
#  'COMPUTED NON-HISPANIC WHITES/ALL OTHERS',
#  'COMPUTED NUMBER OF CHILDREN IN HOUSEHOLD',
#  'COMPUTED NUMBER OF DRINKS OF ALCOHOL BEV',
#  'COMPUTED OTHER VEGETABLE INTAKE IN TIMES',
#  'COMPUTED PHYSICAL HEALTH STATUS',
#  'COMPUTED POTATO SERVINGS PER DAY',
#  'COMPUTED PREFERRED RACE',
#  'COMPUTED RACE GROUPS USED FOR INTERNET P',
#  'COMPUTED RACE-ETHNICITY GROUPING',
#  'COMPUTED SMOKING STATUS',
#  'COMPUTED WEIGHT IN KILOGRAMS',
#  'CONSUME FRUIT 1 OR MORE TIMES PER DAY',
#  'CONSUME VEGETABLES 1 OR MORE TIMES PER D',
#  'CORRECT PHONE NUMBER?',
#  'CORRECT TELEPHONE NUMBER?',
#  'COULD NOT GET MEDICINE DUE TO COST',
#  'COULD NOT SEE DR. BECAUSE OF COST',
#  'CURRENT ASTHMA CALCULATED VARIABLE',
#  'CURRENT E-CIGARETTE USER CALCULATED VARI',
#  'CURRENT SMOKING CALCULATED VARIABLE',
#  'CURRENTLY HAVE HEALTH CARE BILLS',
#  'CURRENTLY HAVE PHYSICAL PAIN FROM CANCER',
#  'CURRENTLY RECEIVING TREATMENT FOR CANCER',
#  'CURRENTLY TAKING BLOOD PRESSURE MEDICATI',
#  'CURRENTLY TAKING MEDICINE FOR HIGH CHOLE',
#  'DAYS HAD TROUBLE WITH SLEEP',
#  'DAYS IN PAST 30 HAD ALCOHOLIC BEVERAGE',
#  'DAYS USED PRESCRIBED PREVENTATIVE ASTHMA',
#  'DELAYED GETTING MEDICAL CARE',
#  'DELAYED GETTING MEDICAL CARE OTHER RESPO',
#  'DESIGN WEIGHT USED IN RAKING',
#  'DID HEALTH INSURANCE PAY FOR ALL OF YOUR',
#  'DID YOU COUGH UP PHLEGM?',
#  'DID YOU DO ANYTHING TO KEEP FROM GETTING',
#  'DID YOU HAVE A COUGH?',
#  'DID YOU HAVE A CT OR CAT SCAN?',
#  'DID YOU HAVE SHORTNESS OF BREATH?',
#  'DID YOU RECEIVE A SUMMARY OF CANCER TREA',
#  'DIFFICULTY CONCENTRATING OR REMEMBERING',
#  'DIFFICULTY DOING ERRANDS ALONE',
#  'DIFFICULTY DRESSING OR BATHING',
#  'DIFFICULTY WALKING OR CLIMBING STAIRS',
#  'DO ANY HIGH RISK SITUATIONS APPLY',
#  'DO YOU ALSO HAVE A LANDLINE TELEPHONE?',
#  'DO YOU CONSIDER YOURSELF TO BE TRANSGEND',
#  'DO YOU CURRENTLY LIVE IN  ____(STATE)___',
#  'DO YOU EXPECT TO HAVE A RELATIVE YOU WIL',
#  'DO YOU HAVE A CELL PHONE FOR PERSONAL US',
#  'DO YOU HAVE MEDICARE?',
#  'DO YOU LIVE IN A PRIVATE RESIDENCE?',
#  'DO YOU LIVE IN COLLEGE HOUSING?',
#  'DO YOU LIVE IN COLLEGE HOUSING?.1',
#  'DO YOU NOW USE E-CIGARETTES, EVERY DAY,',
#  'DOCTOR ADVISED REDUCED SODIUM/SALT INTAK',
#  'DOCTOR VISITS PAST 12 MONTHS',
#  'DOES ARTHRITIS AFFECT WHETHER YOU WORK',
#  'DOES CONFUSION OR MEMORY LOSS INTERFERE',
#  'DR. SUGGEST LOSE WEIGHT FOR ARTHRITIS OR',
#  'DR. SUGGEST USE OF PHYSICAL ACTIVITY OR',
#  'DRINK ANY ALCOHOLIC BEVERAGES IN PAST 30',
#  'DUAL PHONE USE CATEGORIES',
#  'DUAL PHONE USE CORRECTION FACTOR',
#  'DURING THE PAST 30 DAYS, HOW DID YOU PRI',
#  'DURING THE PAST 30 DAYS, ON HOW MANY DAY',
#  'EDUCATION LEVEL',
#  'EMERGENCY ASTHMA CARE DURING PAST 12 MON',
#  'EMPLOYMENT STATUS',
#  'ESTIMATED ACTIVITY INTENSITY FOR FIRST A',
#  'ESTIMATED ACTIVITY INTENSITY FOR SECOND',
#  'ESTIMATED AGE-GENDER SPECIFIC MAXIMUM OX',
#  'ESTIMATED FUNCTIONAL CAPACITY',
#  'EVER BEEN TESTED FOR HIV CALCULATED VARI',
#  'EVER BEEN TOLD YOU HAVE PRE-DIABETES OR',
#  'EVER DENIED INSURANCE COVERAGE BECAUSE O',
#  'EVER DIAGNOSED WITH A STROKE',
#  'EVER DIAGNOSED WITH ANGINA OR CORONARY H',
#  'EVER DIAGNOSED WITH HEART ATTACK',
#  'EVER HAD THE HPV VACCINATION?',
#  'EVER RECEIVE INSTRUCTIONS FROM A DOCTOR',
#  'EVER TAKEN CLASS IN MANAGING ARTHRITIS O',
#  'EVER TAKEN CLASS IN MANAGING DIABETES',
#  'EVER TESTED HIV',
#  'EVER TOLD BLOOD CHOLESTEROL HIGH',
#  'EVER TOLD BLOOD PRESSURE HIGH',
#  'EVER TOLD DIABETES HAS AFFECTED EYES',
#  'EVER TOLD HAD ASTHMA',
#  'EVER TOLD YOU HAD A DEPRESSIVE DISORDER',
#  'EXERCISE IN PAST 30 DAYS',
#  'EXERCISING TO LOWER BP?',
#  'FILE MONTH',
#  'FINAL CHILD WEIGHT: LAND-LINE AND CELL-P',
#  'FINAL DISPOSITION',
#  'FINAL WEIGHT: LAND-LINE AND CELL-PHONE D',
#  'FLU SHOT CALCULATED VARIABLE',
#  'FRENCH FRY INTAKE IN TIMES PER DAY',
#  'FREQUENCY OF DAYS NOW SMOKING',
#  'FRUIT EXCLUSION FROM ANALYSES',
#  'GENDER OF CHILD',
#  'GENERAL HEALTH',
#  'GIVEN UP DAY-TO-DAY CHORES DUE TO CONFUS',
#  'HAD A TEST FOR HIGH BLOOD SUGAR IN PAST',
#  'HAS ANYONE EVER OBSERVED THAT YOU STOP B',
#  'HAVE ANY HEALTH CARE COVERAGE',
#  'HAVE YOU DISCUSSED YOUR CONFUSION OR MEM',
#  'HAVE YOU EVER BEEN GIVEN A BREATHING TES',
#  'HAVE YOU EVER BEEN TOLD THAT YOU SNORE L',
#  'HAVE YOU EVER HAD THE SHINGLES OR ZOSTER',
#  'HAVE YOU EVER USED AN E-CIGARETTE OR OTH',
#  'HAVE YOU EXPERIENCED CONFUSION OR MEMORY',
#  'HEALTH MAKES TAKING ASPIRIN UNSAFE',
#  'HEAVY ALCOHOL CONSUMPTION  CALCULATED VA',
#  'HIGH BLOOD PRESSURE CALCULATED VARIABLE',
#  'HIGH CHOLESTEROL CALCULATED VARIABLE',
#  'HISPANIC, LATINO/A, OR SPANISH ORIGIN CA',
#  'HLTH CARE PRO EVER ADVISED CHANGE IN EAT',
#  'HLTH CARE PRO EVER ADVISED EXERCISE TO R',
#  'HLTH CARE PRO EVER ADVISED MEDS TO REDUC',
#  'HLTH CARE PRO EVER ADVISED REDUCED ALCOH',
#  'HLTH CARE PRO EVER ADVISED USING LESS SA',
#  'HLTH PRO EVER SAID CHILD HAS ASTHMA',
#  'HOUSEHOLD TELEPHONES',
#  'HOW BAD WAS JOINT PAIN',
#  'HOW DO YOUR FINANCES USUALLY WORK OUT AT',
#  'HOW LONG PROVIDED CARE FOR PERSON.',
#  'HOW LONG SINCE CHOLESTEROL CHECKED',
#  'HOW MANY DAYS DEPRESSED IN PAST 30 DAYS',
#  'HOW MANY DAYS FELT ANXIOUS IN PAST 30 DA',
#  'HOW MANY DAYS FULL OF ENERGY IN PAST 30',
#  'HOW MANY DAYS HARD TO DO USUAL ACTIVITIE',
#  'HOW MANY HOURS DO YOU PROVIDE CARE FOR P',
#  'HOW MANY TIMES DID YOU DO PHYSICAL ACTIV',
#  'HOW MANY TIMES DID YOU DRINK 100 PERCENT',
#  'HOW MANY TIMES DID YOU EAT DARK GREEN VE',
#  'HOW MANY TIMES DID YOU EAT FRUIT?',
#  'HOW MANY TIMES HAVE YOU MOVED?',
#  'HOW MANY TIMES WALKING, RUNNING, JOGGING',
#  'HOW MANY TIMES WALKING, RUNNING, JOGGING.1',
#  'HOW MANY TYPES OF CANCER?',
#  'HOW MANY YEARS HAVE YOU SMOKED TOBACCO P',
#  'HOW MUCH TIME DO YOU SLEEP',
#  'HOW OFTEN CHECK BLOOD FOR GLUCOSE',
#  'HOW OFTEN CHECK FEET FOR SORES OR IRRITA',
#  'HOW OFTEN DID YOU DRINK REGULAR SODA OR',
#  'HOW OFTEN DID YOU DRINK SUGAR-SWEETENED',
#  'HOW OFTEN DO YOU EAT FRENCH FRIES OR FRI',
#  'HOW OFTEN DO YOU EAT FRENCH FRIES OR FRI.1',
#  'HOW OFTEN DO YOU EAT FRENCH FRIES OR FRI.2',
#  'HOW OFTEN GET EMOTIONAL SUPPORT NEEDED',
#  'HOW OFTEN HAVE YOU FELT THIS KIND OF STR',
#  'HOW OFTEN USE SEATBELTS IN CAR?',
#  'HOW OLD WHEN YOU FIRST STARTED SMOKING?',
#  'HOW OLD WHEN YOU LAST SMOKED?',
#  'IMPUTED AGE IN SIX GROUPS',
#  'IMPUTED AGE VALUE COLLAPSED ABOVE 80',
#  'IMPUTED RACE/ETHNICITY VALUE',
#  'INCOME LEVEL',
#  'INSTRUCTIONS WRITTEN OR PRINTED',
#  'INTERNET USE IN THE PAST 30 DAYS?',
#  'INTERVAL SINCE LAST SMOKED',
#  'INTERVIEW DATE',
#  'INTERVIEW DAY',
#  'INTERVIEW MONTH',
#  'INTERVIEW YEAR',
#  'IS PAIN UNDER CONTROL?',
#  'IS THIS A CELL TELEPHONE?',
#  'LANGUAGE IDENTIFIER',
#  'LAST EYE EXAM WHERE PUPILS WERE DILATED',
#  'LEISURE TIME PHYSICAL ACTIVITY CALCULATE',
#  'LENGTH OF TIME SINCE LAST ROUTINE CHECKU',
#  'LIFETIME ASTHMA CALCULATED VARIABLE',
#  'LIMITED BECAUSE OF JOINT SYMPTOMS',
#  'LIMITED SOCIAL ACTIVITIES',
#  'LIMITED USUAL ACTIVITIES',
#  'LIMITED WORK ACTIVITIES',
#  'MANAGED HOUSEHOLD TASKS',
#  'MANAGED PERSONAL CARE',
#  'MARITAL STATUS',
#  'METROPOLITAN STATUS CODE',
#  'MINUTES OF FIRST ACTIVITY',
#  'MINUTES OF PHYSICAL ACTIVITY PER WEEK FO',
#  'MINUTES OF PHYSICAL ACTIVITY PER WEEK FO.1',
#  'MINUTES OF PHYSICAL ACTIVITY PER WEEK FO.2',
#  'MINUTES OF PHYSICAL ACTIVITY PER WEEK FO.3',
#  'MINUTES OF SECOND ACTIVITY',
#  'MINUTES OF TOTAL PHYSICAL ACTIVITY PER W',
#  'MINUTES OF TOTAL VIGOROUS PHYSICAL ACTIV',
#  'MINUTES OF VIGOROUS PHYSICAL ACTIVITY PE',
#  'MINUTES OF VIGOROUSPHYSICAL ACTIVITY PER',
#  'MINUTES OR HOURS WALKING, RUNNING, JOGGI',
#  'MINUTES OR HOURS WALKING, RUNNING, JOGGI.1',
#  'MISSING ANY FRUIT RESPONSES',
#  'MISSING ANY VEGETABLE RESPONSES',
#  'MISSING PHYSICAL ACTIVITY DATA',
#  'MONTH AND YEAR OF LAST HIV TEST',
#  'MOST DRINKS ON SINGLE OCCASION PAST 30 D',
#  'MULTIPLE HEALTH CARE PROFESSIONALS',
#  'MUSCLE STRENGTHENING RECOMMENDATION',
#  'NAMTRIBE',
#  'NEED ASSISTANCE WITH DAY-TO_DAY ACTIVITI',
#  'NEIGHBORHOOD SAFE FROM CRIME',
#  'NO MONEY FOR BALANCED MEALS?',
#  'NO MONEY FOR FOOD?',
#  'NOW TAKING INSULIN',
#  'NUMBER OF ADULT MEN IN HOUSEHOLD',
#  'NUMBER OF ADULT WOMEN IN HOUSEHOLD',
#  'NUMBER OF ADULTS IN HOUSEHOLD',
#  'NUMBER OF ADULTS IN HOUSEHOLD.1',
#  'NUMBER OF CHILDREN IN HOUSEHOLD',
#  'NUMBER OF DAYS MENTAL HEALTH NOT GOOD',
#  'NUMBER OF DAYS PHYSICAL HEALTH NOT GOOD',
#  'NUMBER OF HPV SHOTS RECEIVED',
#  'OFFERED ADVICE ABOUT WHAT LEVEL OF DRINK',
#  'ON AVERAGE, HOW MANY CIGARETTES DO YOU S',
#  'ORACE3',
#  'OTHER TYPE OF PHYSICAL ACTIVITY GIVING M',
#  'OUTPATIENT REHAB AFTER HEART ATTACK HOSP',
#  'OUTPATIENT REHAB AFTER HOSP STAY FOR STR',
#  'OVER THE LAST 2 WEEKS, HOW MANY DAYS DID',
#  'OVERWEIGHT OR OBESE CALCULATED VARIABLE',
#  'OWN OR RENT HOME',
#  'PARTICIPATE IN CLINICAL TRIAL AS PART OF',
#  'PHYSICAL ACTIVITY CATEGORIES',
#  'PHYSICAL ACTIVITY FREQUENCY PER WEEK FOR',
#  'PHYSICAL ACTIVITY FREQUENCY PER WEEK FOR.1',
#  'PHYSICAL ACTIVITY INDEX',
#  'PNEUMONIA SHOT EVER',
#  'PNEUMONIA VACCINATION CALCULATED VARIABL',
#  'POOR PHYSICAL OR MENTAL HEALTH',
#  'PRECALL',
#  'PREFERRED CHILD RACE CATEGORIES',
#  'PREGNANCY STATUS',
#  'PRIMARY HEALTH INSURANCE COVERAGE',
#  'PRIMARY SAMPLING UNIT',
#  'PRIVATE RESIDENCE?',
#  'PROVIDED REGULAR CARE FOR FAMILY OR FRIE',
#  'QUESTIONNAIRE VERSION IDENTIFIER',
#  'RAW WEIGHTING FACTOR USED IN RAKING',
#  'RCSBRAC2',
#  'RECEIVED TETANUS SHOT SINCE 2005?',
#  'REDUCE ALCOHOL USE FOR BP?',
#  'REDUCE SALT INTAKE TO LOWER BP?',
#  'RELATIONSHIP OF PERSON TO WHOM YOU ARE G',
#  'RELATIONSHIP TO CHILD',
#  'REPORTED AGE IN FIVE-YEAR AGE CATEGORIES',
#  'REPORTED AGE IN TWO AGE GROUPS CALCULATE',
#  'REPORTED CONSUMING FRUIT >16/DAY',
#  'REPORTED CONSUMING VEGETABLES >23/DAY',
#  'REPORTED HEIGHT IN FEET AND INCHES',
#  'REPORTED WEIGHT IN POUNDS',
#  'RESIDENT OF STATE',
#  'RESIDENTIAL PHONES',
#  'RESPONDENTS AGED 18-64 WITH HEALTH CARE',
#  'RESPONDENTS DIAGNOSED WITH ARTHRITIS',
#  'RESPONDENTS SEX',
#  'RESPONDENTS THAT HAVE EVER REPORTED HAVI',
#  'ROUTINE ASTHMA CARE DURING PAST 12 MONTH',
#  'RSNMRJNA',
#  'RSPSTAT1',
#  'SAFE TIME TO TALK?',
#  'SAMPLE DESIGN STRATIFICATION VARIABLE',
#  'SATISFACTION WITH LIFE',
#  'SATISFIED WITH CARE RECEIVED',
#  'SECSCRFL',
#  'SEXUAL ORIENTATION OR GENDER IDENTITY',
#  'SLEEP DIFFICULTY DUE TO ASTHMA DURING PA',
#  'SMOKED AT LEAST 100 CIGARETTES',
#  'SOCIAL ACTIVITIES LIMITED BECAUSE OF JOI',
#  'STATE FIPS CODE',
#  'STILL HAVE ASTHMA',
#  'STOPPED SMOKING IN PAST 12 MONTHS',
#  'STRATUM WEIGHT',
#  'STRENGTH ACTIVITY FREQUENCY PER WEEK',
#  'TAKE ASPIRIN DAILY OR EVERY OTHER DAY',
#  'TAKE ASPIRIN TO REDUCE CHANCE OF HEART A',
#  'TAKE ASPIRIN TO REDUCE CHANCE OF STROKE',
#  'TAKE ASPIRIN TO RELIEVE PAIN',
#  'THE NUMBER OF MISSING FRUIT RESPONSES',
#  'THE NUMBER OF MISSING VEGETABLE RESPONSE',
#  'TIME SINCE LAST HAD HEALTH CARE COVERAGE',
#  'TIMES CHECKED FOR GLYCOSYLATED HEMOGLOBI',
#  'TIMES FEET CHECK FOR SORES/IRRITATIONS',
#  'TIMES SEEN HEALTH PROFESSIONAL FOR DIABE',
#  'TIMES USED ASTHMA INHALER DURING AN ATTA',
#  'TOLD HAD HIGH BP DURING 2+ VISITS TO HLT',
#  'TOLD HAVE ARTHRITIS',
#  'TOTAL FRUITS CONSUMED PER DAY',
#  'TOTAL VEGETABLES CONSUMED PER DAY',
#  'TRUNCATED DESIGN WEIGHT USED IN ADULT CO',
#  'TYPE OF CANCER',
#  'TYPE OF PHYSICAL ACTIVITY',
#  'URGENT ASTHMA TREATMENT DURING PAST 12 M',
#  'USE OF SMOKELESS TOBACCO PRODUCTS',
#  'VEGETABLE EXCLUSION FROM ANALYSES',
#  'WATCHING SODIUM OR SALT INTAKE',
#  'WDHOWOFT',
#  'WDSHARE',
#  'WDUSENOW',
#  'WERE YOU ADVISED TO REDUCE OR QUIT YOUR',
#  'WERE YOU NOT ABLE TO PAY YOUR BILLS?',
#  'WHAT CAN YOU DO BECAUSE OF ARTHRITIS OR',
#  'WHAT DID YOU DO TO KEEP YOU FROM GETTING',
#  'WHAT IS THE MAJOR HEALTH PROBLEM, ILLNES',
#  'WHAT TYPE OF DOCTOR PROVIDES MAJORITY OF',
#  'WHAT WAS MAIN REASON FOR NOT DOING ANYTH',
#  'WHEN RECEIVED MOST RECENT SEASONAL FLU S',
#  'WHEN YOU NEED HELP WITH DAY-TO-DAY ACTIV',
#  'WHERE DID YOU GET YOUR LAST FLU SHOT/VAC',
#  'WHICH SUPPORT DO YOU MOST NEED THAT YOU',
#  'WITHOUT HEALTH CARE COVERAGE PAST 12 MON',
#  '_DENSTR2',
#  '_IMPAGE',
#  '_IMPCAGE',
#  '_IMPCRAC',
#  '_IMPCSEX',
#  '_IMPEDUC',
#  '_IMPHOME',
#  '_IMPMRTL',
#  '_IMPNPH',
#  '_IMPSEX',
#  '_M_RACE',
#  '_URBNRRL']

# %%
# Find the columns that contain smoking key word

filterList = ['smok','cig']
def containsKeyword(sent):
    sent = sent.lower()
    for f in filterList:
        if f in sent:
            return True
    return False
    
smokecols = [c for c in df.columns if containsKeyword(c)]
smokecols
# Out:
# ['SMOKED AT LEAST 100 CIGARETTES',
#  'FREQUENCY OF DAYS NOW SMOKING',
#  'STOPPED SMOKING IN PAST 12 MONTHS',
#  'INTERVAL SINCE LAST SMOKED',
#  'USE OF SMOKELESS TOBACCO PRODUCTS',
#  'HAVE YOU EVER USED AN E-CIGARETTE OR OTH',
#  'DO YOU NOW USE E-CIGARETTES, EVERY DAY,',
#  'HOW MANY YEARS HAVE YOU SMOKED TOBACCO P',
#  'HOW OLD WHEN YOU FIRST STARTED SMOKING?',
#  'HOW OLD WHEN YOU LAST SMOKED?',
#  'ON AVERAGE, HOW MANY CIGARETTES DO YOU S',
#  'COMPUTED SMOKING STATUS',
#  'CURRENT SMOKING CALCULATED VARIABLE',
#  'COMPUTED E-CIGARETTE USER STATUS',
#  'CURRENT E-CIGARETTE USER CALCULATED VARI']

# %%
# See some values in smoking columns
df[smokecols][:5]
# Out:
#   SMOKED AT LEAST 100 CIGARETTES FREQUENCY OF DAYS NOW SMOKING  \
# 0                             No          Not asked or Missing
# 1                             No          Not asked or Missing
# 2                             No          Not asked or Missing
# 3                             No          Not asked or Missing
# 4                            Yes                    Not at all
#
#   STOPPED SMOKING IN PAST 12 MONTHS  \
# 0              Not asked or Missing
# 1              Not asked or Missing
# 2              Not asked or Missing
# 3              Not asked or Missing
# 4              Not asked or Missing
#
#                       INTERVAL SINCE LAST SMOKED  \
# 0                           Not asked or Missing
# 1                           Not asked or Missing
# 2                           Not asked or Missing
# 3                           Not asked or Missing
# 4  Within the past month (less than 1 month ago)
#
#   USE OF SMOKELESS TOBACCO PRODUCTS HAVE YOU EVER USED AN E-CIGARETTE OR OTH  \
# 0                        Not at all                                       No
# 1                        Not at all                                       No
# 2                        Not at all                                       No
# 3                        Not at all                                       No
# 4                        Not at all                                       No
#
#   DO YOU NOW USE E-CIGARETTES, EVERY DAY,  \
# 0                    Not asked or Missing
# 1                    Not asked or Missing
# 2                    Not asked or Missing
# 3                    Not asked or Missing
# 4                    Not asked or Missing
#
#   HOW MANY YEARS HAVE YOU SMOKED TOBACCO P  \
# 0                     Not asked or Missing
# 1                     Not asked or Missing
# 2                     Not asked or Missing
# 3                     Not asked or Missing
# 4                     Not asked or Missing
#
#   HOW OLD WHEN YOU FIRST STARTED SMOKING? HOW OLD WHEN YOU LAST SMOKED?  \
# 0                    Not asked or Missing          Not asked or Missing
# 1                    Not asked or Missing          Not asked or Missing
# 2                    Not asked or Missing          Not asked or Missing
# 3                    Not asked or Missing          Not asked or Missing
# 4                    Not asked or Missing          Not asked or Missing
#
#   ON AVERAGE, HOW MANY CIGARETTES DO YOU S COMPUTED SMOKING STATUS  \
# 0                     Not asked or Missing            Never smoked
# 1                     Not asked or Missing            Never smoked
# 2                     Not asked or Missing            Never smoked
# 3                     Not asked or Missing            Never smoked
# 4                     Not asked or Missing           Former smoker
#
#   CURRENT SMOKING CALCULATED VARIABLE COMPUTED E-CIGARETTE USER STATUS  \
# 0                                  No          Never used E-cigarettes
# 1                                  No          Never used E-cigarettes
# 2                                  No          Never used E-cigarettes
# 3                                  No          Never used E-cigarettes
# 4                                  No          Never used E-cigarettes
#
#   CURRENT E-CIGARETTE USER CALCULATED VARI
# 0         Not currently using E-cigarettes
# 1         Not currently using E-cigarettes
# 2         Not currently using E-cigarettes
# 3         Not currently using E-cigarettes
# 4         Not currently using E-cigarettes

# %%
# See the frequency distribution of smoking columns
for c in smokecols:
    print(c)
    print(df[c].value_counts())
    print()
# Out:
# SMOKED AT LEAST 100 CIGARETTES
# No                      246459
# Yes                     185837
# Not asked or Missing     15962
# Don�t know/Not Sure       1938
# Refused                    446
# Name: SMOKED AT LEAST 100 CIGARETTES, dtype: int64
#
# FREQUENCY OF DAYS NOW SMOKING
# Not asked or Missing    264878
# Not at all              121867
# Every day                44680
# Some days                18882
# Refused                    237
# Don�t Know/Not Sure         98
# Name: FREQUENCY OF DAYS NOW SMOKING, dtype: int64
#
# STOPPED SMOKING IN PAST 12 MONTHS
# Not asked or Missing    387131
# Yes                      35498
# No                       27796
# Don�t know/Not Sure        178
# Refused                     39
# Name: STOPPED SMOKING IN PAST 12 MONTHS, dtype: int64
#
# INTERVAL SINCE LAST SMOKED
# Not asked or Missing                                              328840
# 10 years or more                                                   80302
# Within the past 5 years (1 year but less than 5 years ago)         16240
# Within the past 10 years (5 years but less than 10 years ago)      12278
# Within the past year (6 months but less than 1 year ago)            3932
# Within the past month (less than 1 month ago)                       2742
# Within the past 3 months (1 month but less than 3 months ago)       2653
# Within the past 6 months (3 months but less than 6 months ago)      2469
# Don�t know/Not sure                                                  764
# Never smoked regularly                                               348
# Refused                                                               74
# Name: INTERVAL SINCE LAST SMOKED, dtype: int64
#
# USE OF SMOKELESS TOBACCO PRODUCTS
# Not at all              418110
# Not asked or Missing     16572
# Every day                 8458
# Some days                 6689
# Refused                    640
# Don�t know/Not Sure        173
# Name: USE OF SMOKELESS TOBACCO PRODUCTS, dtype: int64
#
# HAVE YOU EVER USED AN E-CIGARETTE OR OTH
# No                      363247
# Yes                      66880
# Not asked or Missing     19608
# Refused                    622
# Don�t know/Not Sure        285
# Name: HAVE YOU EVER USED AN E-CIGARETTE OR OTH, dtype: int64
#
# DO YOU NOW USE E-CIGARETTES, EVERY DAY,
# Not asked or Missing     383839
# Not at all                53028
# Some days                  8667
# Every day                  5022
# Don�t know / Not sure        56
# Refused                      30
# Name: DO YOU NOW USE E-CIGARETTES, EVERY DAY,, dtype: int64
#
# HOW MANY YEARS HAVE YOU SMOKED TOBACCO P
# Not asked or Missing                         382491
# Never smoked or smoked less than one year     35799
# Number of years                               30391
# Don't know/Not sure                            1787
# Refused                                         174
# Name: HOW MANY YEARS HAVE YOU SMOKED TOBACCO P, dtype: int64
#
# HOW OLD WHEN YOU FIRST STARTED SMOKING?
# Not asked or Missing                 423890
# Age in Years                          25540
# Never smoked cigarettes regularly       725
# Don�t know/Not Sure                     418
# Refused                                  69
# Name: HOW OLD WHEN YOU FIRST STARTED SMOKING?, dtype: int64
#
# HOW OLD WHEN YOU LAST SMOKED?
# Not asked or Missing    426684
# Age in Years             22778
# Don�t know/Not Sure       1023
# Refused                    157
# Name: HOW OLD WHEN YOU LAST SMOKED?, dtype: int64
#
# ON AVERAGE, HOW MANY CIGARETTES DO YOU S
# Not asked or Missing    424659
# Number of cigarettes     24964
# Don�t know/Not Sure        950
# Refused                     69
# Name: ON AVERAGE, HOW MANY CIGARETTES DO YOU S, dtype: int64
#
# COMPUTED SMOKING STATUS
# Never smoked                             246459
# Former smoker                            121867
# Current smoker - now smokes every day     44680
# Current smoker - now smokes some days     18882
# Don�t know/Refused/Missing                18754
# Name: COMPUTED SMOKING STATUS, dtype: int64
#
# CURRENT SMOKING CALCULATED VARIABLE
# No                            368326
# Yes                            63562
# Don�t know/Refused/Missing     18754
# Name: CURRENT SMOKING CALCULATED VARIABLE, dtype: int64
#
# COMPUTED E-CIGARETTE USER STATUS
# Never used E-cigarettes                      363247
# Former E-cigarette user                       53028
# Don�t know/Refused/Missing                    20678
# Current E-cigarette user - uses some days      8667
# Current E-cigarette user - uses every day      5022
# Name: COMPUTED E-CIGARETTE USER STATUS, dtype: int64
#
# CURRENT E-CIGARETTE USER CALCULATED VARI
# Not currently using E-cigarettes    416275
# Don�t know/Refused/Missing           20678
# Current E-cigarette user             13689
# Name: CURRENT E-CIGARETTE USER CALCULATED VARI, dtype: int64

# %% [markdown]
# ### The computed and calculated columns are cleaned data and have fewer missing values

# %%
## Explore the calculated and computed columns
filterList = ['computed', 'calculated']
def containsKeyword(sent):
    sent = sent.lower()
    for f in filterList:
        if f in sent:
            return True
    return False
    
cols = [c for c in df.columns if containsKeyword(c)]
print("Number of calculated/computed columns: ",len(cols))
cols
# Out:
# Number of calculated/computed columns:  41
# ['COMPUTED PHYSICAL HEALTH STATUS',
#  'COMPUTED MENTAL HEALTH STATUS',
#  'HIGH BLOOD PRESSURE CALCULATED VARIABLE',
#  'CHOLESTEROL CHECKED CALCULATED VARIABLE',
#  'HIGH CHOLESTEROL CALCULATED VARIABLE',
#  'LIFETIME ASTHMA CALCULATED VARIABLE',
#  'CURRENT ASTHMA CALCULATED VARIABLE',
#  'COMPUTED ASTHMA STATUS',
#  'COMPUTED PREFERRED RACE',
#  'CALCULATED NON-HISPANIC RACE INCLUDING M',
#  'COMPUTED RACE-ETHNICITY GROUPING',
#  'COMPUTED NON-HISPANIC WHITES/ALL OTHERS',
#  'COMPUTED FIVE LEVEL RACE/ETHNICITY CATEG',
#  'COMPUTED RACE GROUPS USED FOR INTERNET P',
#  'COMPUTED HEIGHT IN INCHES',
#  'COMPUTED HEIGHT IN METERS',
#  'COMPUTED WEIGHT IN KILOGRAMS',
#  'COMPUTED BODY MASS INDEX',
#  'COMPUTED BODY MASS INDEX CATEGORIES',
#  'OVERWEIGHT OR OBESE CALCULATED VARIABLE',
#  'COMPUTED NUMBER OF CHILDREN IN HOUSEHOLD',
#  'COMPUTED LEVEL OF EDUCATION COMPLETED CA',
#  'COMPUTED INCOME CATEGORIES',
#  'COMPUTED SMOKING STATUS',
#  'CURRENT SMOKING CALCULATED VARIABLE',
#  'COMPUTED E-CIGARETTE USER STATUS',
#  'CURRENT E-CIGARETTE USER CALCULATED VARI',
#  'COMPUTED DRINK-OCCASIONS-PER-DAY',
#  'BINGE DRINKING CALCULATED VARIABLE',
#  'COMPUTED NUMBER OF DRINKS OF ALCOHOL BEV',
#  'HEAVY ALCOHOL CONSUMPTION  CALCULATED VA',
#  'COMPUTED FRUIT JUICE INTAKE IN TIMES PER',
#  'COMPUTED FRUIT INTAKE IN TIMES PER DAY',
#  'COMPUTED DARK GREEN VEGETABLE INTAKE IN',
#  'COMPUTED POTATO SERVINGS PER DAY',
#  'COMPUTED OTHER VEGETABLE INTAKE IN TIMES',
#  '150 MINUTE PHYSICAL ACTIVITY CALCULATED',
#  '300 MINUTE PHYSICAL ACTIVITY CALCULATED',
#  'FLU SHOT CALCULATED VARIABLE',
#  'PNEUMONIA VACCINATION CALCULATED VARIABL',
#  'EVER BEEN TESTED FOR HIV CALCULATED VARI']

# %% [markdown]
# ### These 41 columns calculated columns cover most socieconomic features so they should be used for initial models

# %%
for c in cols:
    print(c)
    print(df[c].value_counts())
    print()
# Out:
# COMPUTED PHYSICAL HEALTH STATUS
# Zero days when physical health not good    276509
# 1-13 days when physical health not good    103480
# 14+ days when physical health not good      61308
# Don�t know/Refused/Missing                   9345
# Name: COMPUTED PHYSICAL HEALTH STATUS, dtype: int64
#
# COMPUTED MENTAL HEALTH STATUS
# Zero days when mental health not good    300525
# 1-13 days when mental health not good     93057
# 14+ days when mental health not good      49846
# Don�t know/Refused/Missing                 7214
# Name: COMPUTED MENTAL HEALTH STATUS, dtype: int64
#
# HIGH BLOOD PRESSURE CALCULATED VARIABLE
# No                                     267905
# Yes                                    181337
# Don�t know/Not Sure/Refused/Missing      1400
# Name: HIGH BLOOD PRESSURE CALCULATED VARIABLE, dtype: int64
#
# CHOLESTEROL CHECKED CALCULATED VARIABLE
# Had cholesterol checked in past 5 years             385747
# Have never had cholesterol checked                   26532
# Don�t know/Not Sure Or Refused/Missing               21776
# Did not have cholesterol checked in past 5 years     16587
# Name: CHOLESTEROL CHECKED CALCULATED VARIABLE, dtype: int64
#
# HIGH CHOLESTEROL CALCULATED VARIABLE
# No         242173
# Yes        156834
# Missing     51635
# Name: HIGH CHOLESTEROL CALCULATED VARIABLE, dtype: int64
#
# LIFETIME ASTHMA CALCULATED VARIABLE
# No                                        386662
# Yes                                        62515
# Don�t know/Not Sure Or Refused/Missing      1465
# Name: LIFETIME ASTHMA CALCULATED VARIABLE, dtype: int64
#
# CURRENT ASTHMA CALCULATED VARIABLE
# No                                        405107
# Yes                                        42319
# Don�t know/Not Sure Or Refused/Missing      3216
# Name: CURRENT ASTHMA CALCULATED VARIABLE, dtype: int64
#
# COMPUTED ASTHMA STATUS
# Never                                     386662
# Current                                    42319
# Former                                     18445
# Don�t know/Not Sure Or Refused/Missing      3216
# Name: COMPUTED ASTHMA STATUS, dtype: int64
#
# COMPUTED PREFERRED RACE
# White                                        363990
# Black or African American                     39190
# Asian                                         10960
# American Indian or Alaskan Native             10721
# Other race                                    10072
# Refused                                        7017
# Don�t know/Not sure                            4123
# Native Hawaiian or other Pacific Islander      3127
# No preferred race                              1437
# Missing                                           5
# Name: COMPUTED PREFERRED RACE, dtype: int64
#
# CALCULATED NON-HISPANIC RACE INCLUDING M
# White only                                        359454
# Black or African American only                     38015
# Multiracial                                        10310
# Asian Only                                         10175
# American Indian or Alaskan Native only              9828
# Other race only                                     9799
# Refused                                             7017
# Don�t know/Not sure                                 4123
# Native Hawaiian or other Pacific Islander only      1916
# Missing                                                5
# Name: CALCULATED NON-HISPANIC RACE INCLUDING M, dtype: int64
#
# COMPUTED RACE-ETHNICITY GROUPING
# White only, non-Hispanic                                        337346
# Hispanic                                                         37114
# Black only, non-Hispanic                                         36117
# Asian only, non-Hispanic                                          9864
# Multiracial, non-Hispanic                                         9187
# Don�t know/Not sure/Refused                                       8764
# American Indian or Alaskan Native only, Non-Hispanic              8384
# Other race only, non-Hispanic                                     2314
# Native Hawaiian or other Pacific Islander only, Non-Hispanic      1552
# Name: COMPUTED RACE-ETHNICITY GROUPING, dtype: int64
#
# COMPUTED NON-HISPANIC WHITES/ALL OTHERS
# Non-Hispanic White             337346
# Non-White or Hispanic          104532
# Don�t know/Not sure/Refused      8764
# Name: COMPUTED NON-HISPANIC WHITES/ALL OTHERS, dtype: int64
#
# COMPUTED FIVE LEVEL RACE/ETHNICITY CATEG
# White only, Non-Hispanic         337346
# Hispanic                          37114
# Black only, Non-Hispanic          36117
# Other race only, Non-Hispanic     22114
# Multiracial, Non-Hispanic          9187
# Don�t know/Not sure/Refused        8764
# Name: COMPUTED FIVE LEVEL RACE/ETHNICITY CATEG, dtype: int64
#
# COMPUTED RACE GROUPS USED FOR INTERNET P
# White - Non-Hispanic                              337346
# Hispanic                                           37114
# Black - Non-Hispanic                               36117
# Other race only, Non-Hispanic                      22114
# Multiracial, Non-Hispanic                           9187
# Don�t know/Not sure/Refused component question      8764
# Name: COMPUTED RACE GROUPS USED FOR INTERNET P, dtype: int64
#
# COMPUTED HEIGHT IN INCHES
# Height in inches                           432579
# Don�t know/Refused/Not asked or Missing     18063
# Name: COMPUTED HEIGHT IN INCHES, dtype: int64
#
# COMPUTED HEIGHT IN METERS
# Height in meters [2 implied decimal places]    434178
# Don�t know/Refused/Not asked or Missing         16464
# Name: COMPUTED HEIGHT IN METERS, dtype: int64
#
# COMPUTED WEIGHT IN KILOGRAMS
# 9072.0     22954
# 8165.0     20917
# 6804.0     20336
# 7257.0     19196
# 7711.0     17324
# 8618.0     14768
# 6350.0     14668
# 7938.0     12263
# 7484.0     11407
# 5897.0     11351
# 9979.0     10566
# 8391.0     10551
# 9525.0      9701
# 6577.0      9426
# 6123.0      9111
# 7031.0      8591
# 10433.0     8031
# 11340.0     7768
# 8845.0      7338
# 5443.0      7281
# 5670.0      6896
# 10886.0     6809
# 9752.0      5275
# 9299.0      4830
# 10206.0     4787
# 11793.0     3813
# 5216.0      3689
# 4990.0      3331
# 10659.0     2971
# 13608.0     2517
#            ...
# 11300.0        1
# 15400.0        1
# 11800.0        1
# 17735.0        1
# 18300.0        1
# 10900.0        1
# 19913.0        1
# 22770.0        1
# 26082.0        1
# 23042.0        1
# 12900.0        1
# 24000.0        1
# 25401.0        1
# 2676.0         1
# 15600.0        1
# 21863.0        1
# 13600.0        1
# 18552.0        1
# 15200.0        1
# 18000.0        1
# 2631.0         1
# 24630.0        1
# 12300.0        1
# 22045.0        1
# 2313.0         1
# 11100.0        1
# 2585.0         1
# 24313.0        1
# 24267.0        1
# 20729.0        1
# Name: COMPUTED WEIGHT IN KILOGRAMS, Length: 561, dtype: int64
#
# COMPUTED BODY MASS INDEX
# 1 or greater                  414139
# Don�t know/Refused/Missing     36503
# Name: COMPUTED BODY MASS INDEX, dtype: int64
#
# COMPUTED BODY MASS INDEX CATEGORIES
# Overweight                    149325
# Normal Weight                 129084
# Obese                         128792
# Don�t know/Refused/Missing     36503
# Underweight                     6938
# Name: COMPUTED BODY MASS INDEX CATEGORIES, dtype: int64
#
# OVERWEIGHT OR OBESE CALCULATED VARIABLE
# Yes                           278117
# No                            136022
# Don�t know/Refused/Missing     36503
# Name: OVERWEIGHT OR OBESE CALCULATED VARIABLE, dtype: int64
#
# COMPUTED NUMBER OF CHILDREN IN HOUSEHOLD
# No children in household              330593
# One child in household                 47926
# Two children in household              40629
# Three children in household            17825
# Four children in household              6616
# Don�t know/Not sure/Missing             3565
# Five or more children in household      3488
# Name: COMPUTED NUMBER OF CHILDREN IN HOUSEHOLD, dtype: int64
#
# COMPUTED LEVEL OF EDUCATION COMPLETED CA
# Graduated from College or Technical School    168712
# Attended College or Technical School          124783
# Graduated High School                         122713
# Did not graduate High School                   32724
# Don�t know/Not sure/Missing                     1710
# Name: COMPUTED LEVEL OF EDUCATION COMPLETED CA, dtype: int64
#
# COMPUTED INCOME CATEGORIES
# $50,000 or more                 182689
# Don�t know/Not sure/Missing      75173
# $15,000 to less than $25,000     62051
# $35,000 to less than $50,000     53214
# $25,000 to less than $35,000     39785
# Less than $15,000                37730
# Name: COMPUTED INCOME CATEGORIES, dtype: int64
#
# COMPUTED SMOKING STATUS
# Never smoked                             246459
# Former smoker                            121867
# Current smoker - now smokes every day     44680
# Current smoker - now smokes some days     18882
# Don�t know/Refused/Missing                18754
# Name: COMPUTED SMOKING STATUS, dtype: int64
#
# CURRENT SMOKING CALCULATED VARIABLE
# No                            368326
# Yes                            63562
# Don�t know/Refused/Missing     18754
# Name: CURRENT SMOKING CALCULATED VARIABLE, dtype: int64
#
# COMPUTED E-CIGARETTE USER STATUS
# Never used E-cigarettes                      363247
# Former E-cigarette user                       53028
# Don�t know/Refused/Missing                    20678
# Current E-cigarette user - uses some days      8667
# Current E-cigarette user - uses every day      5022
# Name: COMPUTED E-CIGARETTE USER STATUS, dtype: int64
#
# CURRENT E-CIGARETTE USER CALCULATED VARI
# Not currently using E-cigarettes    416275
# Don�t know/Refused/Missing           20678
# Current E-cigarette user             13689
# Name: CURRENT E-CIGARETTE USER CALCULATED VARI, dtype: int64
#
# COMPUTED DRINK-OCCASIONS-PER-DAY
# Drink-Occasions per day                   221510
# No Drink-Occasions per day                203392
# Don�t know/Not Sure Or Refused/Missing     25740
# Name: COMPUTED DRINK-OCCASIONS-PER-DAY, dtype: int64
#
# BINGE DRINKING CALCULATED VARIABLE
# No                            364865
# Yes                            56117
# Don�t know/Refused/Missing     29660
# Name: BINGE DRINKING CALCULATED VARIABLE, dtype: int64
#
# COMPUTED NUMBER OF DRINKS OF ALCOHOL BEV
# Number of drinks per week              217136
# Did not drink                          203392
# Don�t know/Not sure/Refused/Missing     30114
# Name: COMPUTED NUMBER OF DRINKS OF ALCOHOL BEV, dtype: int64
#
# HEAVY ALCOHOL CONSUMPTION  CALCULATED VA
# No                            395942
# Don�t know/Refused/Missing     30228
# Yes                            24472
# Name: HEAVY ALCOHOL CONSUMPTION  CALCULATED VA, dtype: int64
#
# COMPUTED FRUIT JUICE INTAKE IN TIMES PER
# 0.0       173923
# 100.0      62677
# 14.0       26782
# 29.0       24444
# 7.0        19044
# 3.0        18681
# 43.0       17520
# 2.0        10152
# 10.0        8468
# 17.0        7335
# 200.0       7297
# 57.0        7044
# 13.0        5564
# 33.0        4910
# 71.0        4573
# 50.0        4245
# 67.0        2355
# 300.0       2347
# 20.0        1926
# 23.0        1414
# 27.0         934
# 86.0         818
# 400.0        694
# 83.0         684
# 40.0         618
# 500.0        493
# 47.0         380
# 700.0        378
# 143.0        227
# 3000.0       113
#            ...
# 183.0          3
# 293.0          3
# 137.0          2
# 243.0          2
# 107.0          2
# 457.0          2
# 250.0          2
# 714.0          2
# 229.0          1
# 443.0          1
# 514.0          1
# 130.0          1
# 177.0          1
# 160.0          1
# 1414.0         1
# 267.0          1
# 1071.0         1
# 2400.0         1
# 471.0          1
# 386.0          1
# 900.0          1
# 2200.0         1
# 163.0          1
# 2600.0         1
# 2800.0         1
# 283.0          1
# 140.0          1
# 233.0          1
# 1600.0         1
# 253.0          1
# Name: COMPUTED FRUIT JUICE INTAKE IN TIMES PER, Length: 103, dtype: int64
#
# COMPUTED FRUIT INTAKE IN TIMES PER DAY
# 100.0     126727
# 200.0      71640
# 43.0       33976
# 300.0      27700
# 29.0       25481
# 57.0       19689
# 71.0       15624
# 14.0       12881
# 0.0        12774
# 7.0         7695
# 17.0        6327
# 10.0        6077
# 33.0        5820
# 400.0       5352
# 50.0        5069
# 3.0         4704
# 13.0        4487
# 67.0        4270
# 86.0        2739
# 500.0       2605
# 20.0        2045
# 2.0         1992
# 83.0        1507
# 143.0       1343
# 23.0        1227
# 27.0        1011
# 40.0         913
# 700.0        788
# 600.0        567
# 114.0        417
#            ...
# 317.0          2
# 4000.0         2
# 643.0          2
# 123.0          2
# 307.0          2
# 130.0          2
# 857.0          2
# 1071.0         1
# 113.0          1
# 223.0          1
# 8000.0         1
# 3500.0         1
# 160.0          1
# 514.0          1
# 4200.0         1
# 3600.0         1
# 1300.0         1
# 280.0          1
# 213.0          1
# 2600.0         1
# 8800.0         1
# 2900.0         1
# 207.0          1
# 187.0          1
# 757.0          1
# 3300.0         1
# 173.0          1
# 2300.0         1
# 203.0          1
# 1343.0         1
# Name: COMPUTED FRUIT INTAKE IN TIMES PER DAY, Length: 128, dtype: int64
#
# COMPUTED DARK GREEN VEGETABLE INTAKE IN
# 100.0     85004
# 43.0      50843
# 29.0      46566
# 14.0      36953
# 57.0      29985
# 0.0       29721
# 71.0      20377
# 200.0     16109
# 7.0       13413
# 50.0      10198
# 3.0       10129
# 67.0       8437
# 33.0       8176
# 10.0       8149
# 17.0       7860
# 13.0       6753
# 86.0       3463
# 83.0       3420
# 300.0      3328
# 2.0        3301
# 20.0       3033
# 23.0       1866
# 40.0       1858
# 27.0       1822
# 400.0       861
# 500.0       762
# 700.0       545
# 47.0        491
# 93.0        415
# 143.0       363
#           ...
# 127.0         2
# 153.0         2
# 2700.0        2
# 714.0         2
# 3100.0        2
# 371.0         2
# 1414.0        2
# 183.0         2
# 6000.0        1
# 140.0         1
# 4000.0        1
# 123.0         1
# 486.0         1
# 217.0         1
# 343.0         1
# 1600.0        1
# 529.0         1
# 786.0         1
# 2300.0        1
# 386.0         1
# 187.0         1
# 1300.0        1
# 5300.0        1
# 313.0         1
# 5500.0        1
# 686.0         1
# 9000.0        1
# 9100.0        1
# 283.0         1
# 137.0         1
# Name: COMPUTED DARK GREEN VEGETABLE INTAKE IN, Length: 119, dtype: int64
#
# COMPUTED POTATO SERVINGS PER DAY
# 14.0      69190
# 29.0      54389
# 0.0       49870
# 7.0       38460
# 43.0      32885
# 3.0       29797
# 10.0      21350
# 17.0      17626
# 13.0      15912
# 100.0     15691
# 57.0      12923
# 33.0      12309
# 50.0       7047
# 71.0       5987
# 2.0        5962
# 20.0       5554
# 67.0       4643
# 27.0       3073
# 23.0       2882
# 40.0       1676
# 200.0      1405
# 86.0       1104
# 83.0       1036
# 300.0       552
# 47.0        383
# 30.0        278
# 400.0       229
# 53.0        185
# 60.0        183
# 500.0       168
#           ...
# 800.0         6
# 7500.0        5
# 157.0         5
# 110.0         5
# 357.0         5
# 107.0         5
# 457.0         4
# 314.0         3
# 9900.0        3
# 329.0         3
# 471.0         3
# 293.0         2
# 183.0         2
# 1200.0        2
# 137.0         2
# 267.0         1
# 247.0         1
# 257.0         1
# 229.0         1
# 1800.0        1
# 7000.0        1
# 743.0         1
# 1071.0        1
# 210.0         1
# 1400.0        1
# 1100.0        1
# 170.0         1
# 5300.0        1
# 1300.0        1
# 127.0         1
# Name: COMPUTED POTATO SERVINGS PER DAY, Length: 92, dtype: int64
#
# COMPUTED OTHER VEGETABLE INTAKE IN TIMES
# 100.0     150328
# 200.0      49731
# 43.0       33113
# 29.0       25872
# 57.0       23743
# 71.0       20430
# 14.0       15293
# 0.0        10528
# 300.0      10013
# 67.0        9823
# 50.0        7974
# 33.0        6695
# 86.0        5493
# 7.0         5151
# 17.0        4814
# 83.0        4581
# 10.0        3782
# 13.0        3652
# 3.0         3239
# 400.0       2058
# 20.0        2025
# 2.0         1647
# 40.0        1448
# 27.0        1406
# 500.0       1282
# 700.0       1245
# 23.0        1209
# 143.0        765
# 93.0         629
# 330.0        407
#            ...
# 457.0          3
# 9000.0         2
# 571.0          2
# 160.0          2
# 4000.0         2
# 1800.0         2
# 486.0          2
# 120.0          2
# 3100.0         2
# 243.0          2
# 213.0          2
# 1043.0         1
# 130.0          1
# 3600.0         1
# 207.0          1
# 140.0          1
# 1071.0         1
# 971.0          1
# 283.0          1
# 2400.0         1
# 123.0          1
# 3200.0         1
# 203.0          1
# 173.0          1
# 5500.0         1
# 1600.0         1
# 857.0          1
# 5300.0         1
# 343.0          1
# 4200.0         1
# Name: COMPUTED OTHER VEGETABLE INTAKE IN TIMES, Length: 120, dtype: int64
#
# 150 MINUTE PHYSICAL ACTIVITY CALCULATED
# 150+ minutes (or vigorous equivalent minutes) of physical activity      206134
# 0 minutes (or vigorous equivalent minutes) of physical activity         120635
# 1-149 minutes  (or vigorous equivalent minutes) of physical activity     73639
# Don�t know/Not Sure/Refused/Missing                                      50234
# Name: 150 MINUTE PHYSICAL ACTIVITY CALCULATED, dtype: int64
#
# 300 MINUTE PHYSICAL ACTIVITY CALCULATED
# 1-300 minutes  (or vigorous equivalent minutes) of physical activity    144828
# 301+ minutes  (or vigorous equivalent minutes) of physical activity     132418
# 0 minutes  (or vigorous equivalent minutes) of physical activity        120635
# Don�t know/Not Sure/Refused/Missing                                      52761
# Name: 300 MINUTE PHYSICAL ACTIVITY CALCULATED, dtype: int64
#
# FLU SHOT CALCULATED VARIABLE
# Age Less Than 65                          287849
# Yes                                        88535
# No                                         56139
# Don�t know/Not Sure Or Refused/Missing     18119
# Name: FLU SHOT CALCULATED VARIABLE, dtype: int64
#
# PNEUMONIA VACCINATION CALCULATED VARIABL
# Age Less Than 65                          287849
# Yes                                       107390
# No                                         33679
# Don�t know/Not Sure Or Refused/Missing     21724
# Name: PNEUMONIA VACCINATION CALCULATED VARIABL, dtype: int64
#
# EVER BEEN TESTED FOR HIV CALCULATED VARI
# No                             268409
# Yes                            127137
# Not asked or missing            41727
# Don�t know/Not Sure/Refused     13369
# Name: EVER BEEN TESTED FOR HIV CALCULATED VARI, dtype: int64

# %%
# create a datframe that only has calculated columns
comDF = df[cols]
comDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450642 entries, 0 to 450641
# Data columns (total 41 columns):
# COMPUTED PHYSICAL HEALTH STATUS             450642 non-null object
# COMPUTED MENTAL HEALTH STATUS               450642 non-null object
# HIGH BLOOD PRESSURE CALCULATED VARIABLE     450642 non-null object
# CHOLESTEROL CHECKED CALCULATED VARIABLE     450642 non-null object
# HIGH CHOLESTEROL CALCULATED VARIABLE        450642 non-null object
# LIFETIME ASTHMA CALCULATED VARIABLE         450642 non-null object
# CURRENT ASTHMA CALCULATED VARIABLE          450642 non-null object
# COMPUTED ASTHMA STATUS                      450642 non-null object
# COMPUTED PREFERRED RACE                     450642 non-null object
# CALCULATED NON-HISPANIC RACE INCLUDING M    450642 non-null object
# COMPUTED RACE-ETHNICITY GROUPING            450642 non-null object
# COMPUTED NON-HISPANIC WHITES/ALL OTHERS     450642 non-null object
# COMPUTED FIVE LEVEL RACE/ETHNICITY CATEG    450642 non-null object
# COMPUTED RACE GROUPS USED FOR INTERNET P    450642 non-null object
# COMPUTED HEIGHT IN INCHES                   450642 non-null object
# COMPUTED HEIGHT IN METERS                   450642 non-null object
# COMPUTED WEIGHT IN KILOGRAMS                420723 non-null float64
# COMPUTED BODY MASS INDEX                    450642 non-null object
# COMPUTED BODY MASS INDEX CATEGORIES         450642 non-null object
# OVERWEIGHT OR OBESE CALCULATED VARIABLE     450642 non-null object
# COMPUTED NUMBER OF CHILDREN IN HOUSEHOLD    450642 non-null object
# COMPUTED LEVEL OF EDUCATION COMPLETED CA    450642 non-null object
# COMPUTED INCOME CATEGORIES                  450642 non-null object
# COMPUTED SMOKING STATUS                     450642 non-null object
# CURRENT SMOKING CALCULATED VARIABLE         450642 non-null object
# COMPUTED E-CIGARETTE USER STATUS            450642 non-null object
# CURRENT E-CIGARETTE USER CALCULATED VARI    450642 non-null object
# COMPUTED DRINK-OCCASIONS-PER-DAY            450642 non-null object
# BINGE DRINKING CALCULATED VARIABLE          450642 non-null object
# COMPUTED NUMBER OF DRINKS OF ALCOHOL BEV    450642 non-null object
# HEAVY ALCOHOL CONSUMPTION  CALCULATED VA    450642 non-null object
# COMPUTED FRUIT JUICE INTAKE IN TIMES PER    417359 non-null float64
# COMPUTED FRUIT INTAKE IN TIMES PER DAY      416996 non-null float64
# COMPUTED DARK GREEN VEGETABLE INTAKE IN     417323 non-null float64
# COMPUTED POTATO SERVINGS PER DAY            413900 non-null float64
# COMPUTED OTHER VEGETABLE INTAKE IN TIMES    413348 non-null float64
# 150 MINUTE PHYSICAL ACTIVITY CALCULATED     450642 non-null object
# 300 MINUTE PHYSICAL ACTIVITY CALCULATED     450642 non-null object
# FLU SHOT CALCULATED VARIABLE                450642 non-null object
# PNEUMONIA VACCINATION CALCULATED VARIABL    450642 non-null object
# EVER BEEN TESTED FOR HIV CALCULATED VARI    450642 non-null object
# dtypes: float64(6), object(35)
# memory usage: 141.0+ MB

# %%
print(pd.Series.idxmin(comDF['COMPUTED PHYSICAL HEALTH STATUS'].value_counts()))
comDF['COMPUTED PHYSICAL HEALTH STATUS'].value_counts()
# Out:
# Don�t know/Refused/Missing
# Zero days when physical health not good    276509
# 1-13 days when physical health not good    103480
# 14+ days when physical health not good      61308
# Don�t know/Refused/Missing                   9345
# Name: COMPUTED PHYSICAL HEALTH STATUS, dtype: int64

# %%
comDF.describe()
# Out:
#        COMPUTED WEIGHT IN KILOGRAMS  COMPUTED FRUIT JUICE INTAKE IN TIMES PER  \
# count                 420723.000000                             417359.000000
# mean                    8158.443192                                 33.795399
# std                     2069.914152                                103.738742
# min                     2268.000000                                  0.000000
# 25%                     6759.000000                                  0.000000
# 50%                     7938.000000                                  7.000000
# 75%                     9163.000000                                 43.000000
# max                    27500.000000                               9900.000000
#
#        COMPUTED FRUIT INTAKE IN TIMES PER DAY  \
# count                           416996.000000
# mean                               116.103440
# std                                170.791619
# min                                  0.000000
# 25%                                 43.000000
# 50%                                100.000000
# 75%                                200.000000
# max                               9900.000000
#
#        COMPUTED DARK GREEN VEGETABLE INTAKE IN  \
# count                            417323.000000
# mean                                 61.060855
# std                                 133.629245
# min                                   0.000000
# 25%                                  14.000000
# 50%                                  43.000000
# 75%                                 100.000000
# max                                9900.000000
#
#        COMPUTED POTATO SERVINGS PER DAY  \
# count                     413900.000000
# mean                          25.512600
# std                           64.430663
# min                            0.000000
# 25%                            7.000000
# 50%                           14.000000
# 75%                           29.000000
# max                         9900.000000
#
#        COMPUTED OTHER VEGETABLE INTAKE IN TIMES
# count                             413348.000000
# mean                                 100.917307
# std                                  201.645847
# min                                    0.000000
# 25%                                   43.000000
# 50%                                  100.000000
# 75%                                  100.000000
# max                                 9900.000000

# %%
print("Data types and unique values")
[ (comDF[c].dtype.name,len(comDF[c].value_counts()))  for c in comDF.columns]
# Out:
# Data types and unique values
# [('object', 4),
#  ('object', 4),
#  ('object', 3),
#  ('object', 4),
#  ('object', 3),
#  ('object', 3),
#  ('object', 3),
#  ('object', 4),
#  ('object', 10),
#  ('object', 10),
#  ('object', 9),
#  ('object', 3),
#  ('object', 6),
#  ('object', 6),
#  ('object', 2),
#  ('object', 2),
#  ('float64', 561),
#  ('object', 2),
#  ('object', 5),
#  ('object', 3),
#  ('object', 7),
#  ('object', 5),
#  ('object', 6),
#  ('object', 5),
#  ('object', 3),
#  ('object', 5),
#  ('object', 3),
#  ('object', 3),
#  ('object', 3),
#  ('object', 3),
#  ('object', 3),
#  ('float64', 103),
#  ('float64', 128),
#  ('float64', 119),
#  ('float64', 92),
#  ('float64', 120),
#  ('object', 4),
#  ('object', 4),
#  ('object', 4),
#  ('object', 4),
#  ('object', 4)]

# %%
print("NANs for numeric variables")
[ (c, np.sum(np.isnan(comDF[c])))  for c in comDF.columns if np.issubdtype(comDF[c].dtype, np.number) ]
# Out:
# NANs for numeric variables
# [('COMPUTED WEIGHT IN KILOGRAMS', 29919),
#  ('COMPUTED FRUIT JUICE INTAKE IN TIMES PER', 33283),
#  ('COMPUTED FRUIT INTAKE IN TIMES PER DAY', 33646),
#  ('COMPUTED DARK GREEN VEGETABLE INTAKE IN', 33319),
#  ('COMPUTED POTATO SERVINGS PER DAY', 36742),
#  ('COMPUTED OTHER VEGETABLE INTAKE IN TIMES', 37294)]

# %%
print("Records: ",len(comDF))
comDF = comDF.dropna()
print("Records after cleaning Nan: ",len(comDF))
# Out:
# Records:  450642
# Records after cleaning Nan:  379592

# %%
print("Infintes for numeric variables")
[ (c, np.sum(np.isinf(comDF[c])))  for c in comDF.columns if np.issubdtype(comDF[c].dtype, np.number) ]
# Out:
# Infintes for numeric variables
# [('COMPUTED WEIGHT IN KILOGRAMS', 0),
#  ('COMPUTED FRUIT JUICE INTAKE IN TIMES PER', 0),
#  ('COMPUTED FRUIT INTAKE IN TIMES PER DAY', 0),
#  ('COMPUTED DARK GREEN VEGETABLE INTAKE IN', 0),
#  ('COMPUTED POTATO SERVINGS PER DAY', 0),
#  ('COMPUTED OTHER VEGETABLE INTAKE IN TIMES', 0)]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
def labelEncodeCategoricalFeatures(DF):
    df = DF.copy()
    for c in df.columns:
        if df[c].dtype.name == 'object':
            df[c] = labelencoder.fit_transform(df[c])
    return df

# %%
# remove class imballance by sampling from majority class
def classImballanceDownSample(df,ycol):
    df = df.copy()
    valueCount = df[ycol].value_counts()
    print("Before Class Imballance Treatment: ")
    print(valueCount)
    classes = valueCount.index
    counts = valueCount.values
    minClassSize = np.min(counts)
    for clas in classes:
        df1 = df[df[ycol]==clas]
        df2 = df[df[ycol]!=clas]
        
        df1 = df1.sample(n=minClassSize, random_state=50)
        df = df1.append(df2)
    #shuffling the dataframe
    df = df.sample(frac=1).reset_index(drop=True)
    print("After Class Imballance Treatment: ")
    print(df[ycol].value_counts())
    return df

# %%
# remove class imballance by up sampling minority classes
def classImballanceUpSample(df,ycol):
    df = df.copy()
    valueCount = df[ycol].value_counts()
    print("Before Class Imballance Treatment: ")
    print(valueCount)
    classes = valueCount.index
    counts = valueCount.values
    maxClassSize = np.max(counts).astype(float)
    fractions = maxClassSize / counts
    for clas,f in zip(classes,fractions):
        df1 = df[df[ycol]==clas]
        df2 = df[df[ycol]!=clas]
        
        df1 = df1.sample(frac=f, replace=True, random_state=50)
        df = df1.append(df2)
    #shuffling the dataframe
    df = df.sample(frac=1).reset_index(drop=True)
    print("After Class Imballance Treatment: ")
    print(df[ycol].value_counts())
    return df

# %%
# model that trains a default random forest and prints the report
def getModel(df, ballanceClasses=None, rfcBalance = None):
    
    xcols = df.columns[:len(df.columns)-1]
    ycols = [df.columns[-1]]
    print("Predictors: ",len(xcols))
    print("label: ",ycols[0])
    
#     if ballanceClasses != None:
#         df = ballanceClasses(df, ycols[0])
        
    X = df[xcols]
    Y = df[ycols]
    
    X = labelEncodeCategoricalFeatures(X)
    print("Label Encoding.")
    
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42, shuffle=True)
    print("Train Test Split:")
    print(np.array(X_train).shape, np.array(X_test).shape, np.array(y_train).shape, np.array(y_test).shape)
    
    if ballanceClasses != None:
        dfTrain = X_train
        dfTrain['label'] = y_train
        dfTrain = ballanceClasses(dfTrain,'label')
        X_train = dfTrain[ [c for c in dfTrain.columns if c not in 'label'] ]
        y_train = dfTrain['label']
    
    #print("Checking if sampling worked:")
    #print(y_train.value_counts())
    #print()
    
    if rfcBalance == None:
        clf = rfc()
    else:
        clf = rfc(class_weight = rfcBalance)
        print(clf)
    
    #clf = rfc()
    clf.fit(X_train, y_train.values.ravel())
    y_pred = clf.predict(X_test)
    print("Accuracy : ", np.sum(y_test[ycols[0]].values==y_pred).astype(float)/len(y_test) )
    print(classification_report(y_test[ycols[0]].values, y_pred))

# %% [markdown]
# ### Predicting current calculated variables

# %%
## Predicting current calculated variables
xcols = [c for c in cols if c not in smokecols] + ['CURRENT SMOKING CALCULATED VARIABLE']
doesSmokeDf = comDF[xcols]
print("Original: ",len(doesSmokeDf))
doesSmokeDf = doesSmokeDf[doesSmokeDf['CURRENT SMOKING CALCULATED VARIABLE'].apply(lambda x: x in ['Yes','No'])]
print("Cleaned Label: ",len(doesSmokeDf))

print("Columns :",len(doesSmokeDf.columns))
print()
print(doesSmokeDf['CURRENT SMOKING CALCULATED VARIABLE'].value_counts())
# Out:
# Original:  379592
# Cleaned Label:  377922
# Columns : 38
#
# No     322389
# Yes     55533
# Name: CURRENT SMOKING CALCULATED VARIABLE, dtype: int64

# %%
## Without removing the class imballance
getModel(doesSmokeDf)
# Out:
# Predictors:  37
# label:  CURRENT SMOKING CALCULATED VARIABLE
# Label Encoding.
# Train Test Split:
# (253207, 37) (124715, 37) (253207, 1) (124715, 1)
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy :  0.8516377340335965
#               precision    recall  f1-score   support
#
#           No       0.87      0.98      0.92    106363
#          Yes       0.48      0.12      0.20     18352
#
#    micro avg       0.85      0.85      0.85    124715
#    macro avg       0.67      0.55      0.56    124715
# weighted avg       0.81      0.85      0.81    124715

# %% [markdown]
# ### Class imballance is influencing the model to converge towards a biased model. We need to treat class imballance.

# %% [markdown]
# ### Upsampling before test train split gives extremely high accuracy but it is not correct. Because a lot of training examples show up in test and thus we are not actually measuring out of sample performance. So I changed code to treat imballance only in the train data.

# %%
## With upsampling the minority class
getModel(doesSmokeDf, classImballanceUpSample)
# Out:
# Predictors:  37
# label:  CURRENT SMOKING CALCULATED VARIABLE
# Label Encoding.
# Train Test Split:
# (253207, 37) (124715, 37) (253207, 1) (124715, 1)
# Before Class Imballance Treatment:
# No     216026
# Yes     37181
# Name: label, dtype: int64
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# After Class Imballance Treatment:
# No     216026
# Yes    216026
# Name: label, dtype: int64
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy :  0.8334201980515575
#               precision    recall  f1-score   support
#
#           No       0.88      0.93      0.90    106363
#          Yes       0.40      0.27      0.33     18352
#
#    micro avg       0.83      0.83      0.83    124715
#    macro avg       0.64      0.60      0.62    124715
# weighted avg       0.81      0.83      0.82    124715

# %%
## With downsampling the majority class
getModel(doesSmokeDf, classImballanceDownSample)
# Out:
# Predictors:  37
# label:  CURRENT SMOKING CALCULATED VARIABLE
# Label Encoding.
# Train Test Split:
# (253207, 37) (124715, 37) (253207, 1) (124715, 1)
# Before Class Imballance Treatment:
# No     216026
# Yes     37181
# Name: label, dtype: int64
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# After Class Imballance Treatment:
# Yes    37181
# No     37181
# Name: label, dtype: int64
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy :  0.7138756364511085
#               precision    recall  f1-score   support
#
#           No       0.92      0.73      0.81    106363
#          Yes       0.28      0.61      0.39     18352
#
#    micro avg       0.71      0.71      0.71    124715
#    macro avg       0.60      0.67      0.60    124715
# weighted avg       0.82      0.71      0.75    124715

# %% [markdown]
# ### COMPUTED SMOKING STATUS

# %%
## Predicting current calculated variables
xcols = [c for c in cols if c not in smokecols] + ['COMPUTED SMOKING STATUS']
quitSmokeDf = comDF[xcols]
print("Original: ",len(quitSmokeDf))
quitSmokeDf = quitSmokeDf[quitSmokeDf['COMPUTED SMOKING STATUS'].apply(lambda x: x in  \
                                                                       ['Former smoker', \
                                                                        'Current smoker - now smokes every day',\
                                                                      'Current smoker - now smokes some days'])]
quitSmokeDf['COMPUTED SMOKING STATUS'] = quitSmokeDf['COMPUTED SMOKING STATUS'].apply(lambda x: x if 'Current smoker' not in x \
                                                                                     else 'Current smoker')

print("Cleaned Label: ",len(quitSmokeDf))

print("Columns :",len(quitSmokeDf.columns))
print()
print(quitSmokeDf['COMPUTED SMOKING STATUS'].value_counts())
# Out:
# Original:  379592
# Cleaned Label:  162967
# Columns : 38
#
# Former smoker     107434
# Current smoker     55533
# Name: COMPUTED SMOKING STATUS, dtype: int64

# %%
## Without removing the class imballance
getModel(quitSmokeDf)
# Out:
# Predictors:  37
# label:  COMPUTED SMOKING STATUS
# Label Encoding.
# Train Test Split:
# (109187, 37) (53780, 37) (109187, 1) (53780, 1)
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy :  0.6990516920788398
#                 precision    recall  f1-score   support
#
# Current smoker       0.56      0.55      0.55     18151
#  Former smoker       0.77      0.78      0.77     35629
#
#      micro avg       0.70      0.70      0.70     53780
#      macro avg       0.66      0.66      0.66     53780
#   weighted avg       0.70      0.70      0.70     53780

# %%
## With upsampling the minority class
getModel(quitSmokeDf, classImballanceUpSample)
# Out:
# Predictors:  37
# label:  COMPUTED SMOKING STATUS
# Label Encoding.
# Train Test Split:
# (109187, 37) (53780, 37) (109187, 1) (53780, 1)
# Before Class Imballance Treatment:
# Former smoker     71805
# Current smoker    37382
# Name: label, dtype: int64
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# After Class Imballance Treatment:
# Former smoker     71805
# Current smoker    71805
# Name: label, dtype: int64
# Accuracy :  0.6733358125697285
#                 precision    recall  f1-score   support
#
# Current smoker       0.51      0.66      0.58     18151
#  Former smoker       0.80      0.68      0.73     35629
#
#      micro avg       0.67      0.67      0.67     53780
#      macro avg       0.65      0.67      0.66     53780
#   weighted avg       0.70      0.67      0.68     53780

# %%
## With downsampling the majority class
getModel(quitSmokeDf, classImballanceDownSample)
# Out:
# Predictors:  37
# label:  COMPUTED SMOKING STATUS
# Label Encoding.
# Train Test Split:
# (109187, 37) (53780, 37) (109187, 1) (53780, 1)
# Before Class Imballance Treatment:
# Former smoker     71805
# Current smoker    37382
# Name: label, dtype: int64
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# After Class Imballance Treatment:
# Former smoker     37382
# Current smoker    37382
# Name: label, dtype: int64
# Accuracy :  0.6455001859427296
#                 precision    recall  f1-score   support
#
# Current smoker       0.48      0.73      0.58     18151
#  Former smoker       0.82      0.60      0.69     35629
#
#      micro avg       0.65      0.65      0.65     53780
#      macro avg       0.65      0.67      0.64     53780
#   weighted avg       0.70      0.65      0.66     53780

# %% [markdown]
# ### Explore E cigarette smoking

# %%
ecigdf = comDF.copy()
ecigdf.rename(columns={'CURRENT E-CIGARETTE USER CALCULATED VARI': 'esmoke', \
                     'CURRENT SMOKING CALCULATED VARIABLE':'smoke'},inplace = True)


mapper = {'Current E-cigarette user': 'Yes', 'Not currently using E-cigarettes': 'No' }
ecigdf['esmoke'] = ecigdf['esmoke'].map(mapper)

print("data size: ",len(ecigdf))
ecigdf = ecigdf[ecigdf.smoke.apply(lambda x: x in ['Yes','No']) ]
ecigdf = ecigdf[ecigdf.esmoke.apply(lambda x: x in ['Yes','No']) ]
print("clean data size: ",len(ecigdf))

print("Frequency distributions:")
print(ecigdf.esmoke.value_counts())
print(ecigdf.smoke.value_counts())
# Out:
# data size:  379592
# clean data size:  377435
# Frequency distributions:
# No     365208
# Yes     12227
# Name: esmoke, dtype: int64
# No     321970
# Yes     55465
# Name: smoke, dtype: int64

# %%
print("Just smoke :", np.sum((ecigdf.smoke == 'Yes') & (ecigdf.esmoke == 'No')))
print("Just esmoke:", np.sum((ecigdf.smoke == 'No') & (ecigdf.esmoke == 'Yes')))
print("SMoke Both :", np.sum((ecigdf.smoke == 'Yes') & (ecigdf.esmoke == 'Yes')))
print("Smoke none :", np.sum((ecigdf.smoke == 'No') & (ecigdf.esmoke == 'No')))
# Out:
# Just smoke : 48998
# Just esmoke: 5760
# SMoke Both : 6467
# Smoke none : 316210

# %% [markdown]
# ### Assumption: Considering esmokers and those who smoke both as esmokers.

# %%
# remove non smokers
ecigdf = ecigdf[ (ecigdf.smoke == 'Yes') | (ecigdf.esmoke == 'Yes') ]
# remove both smokers
ecigdf = ecigdf[ ~((ecigdf.smoke == 'Yes') & (ecigdf.esmoke == 'Yes')) ]
print("clean data size: ",len(ecigdf))
# Out:
# clean data size:  54758

# %%
# label is 1 for esmoker and zero for non smoker
ecigdf['label'] = ecigdf.esmoke == 'Yes'

# %%
set(ecigdf.label)
# Out:
# {False, True}

# %%
excludecolumns = smokecols + ['esmoke', 'smoke']
ecigdf = ecigdf[[c for c in ecigdf.columns if c not in excludecolumns ]]
print('Columns : ',len(ecigdf.columns))
print("Frequency distributions:")
print(ecigdf.label.value_counts())
# Out:
# Columns :  38
# Frequency distributions:
# False    48998
# True      5760
# Name: label, dtype: int64

# %%
## Without removing the class imballance
getModel(ecigdf)
# Out:
# Predictors:  37
# label:  label
# Label Encoding.
# Train Test Split:
# (36687, 37) (18071, 37) (36687, 1) (18071, 1)
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy :  0.8928670245144154
#               precision    recall  f1-score   support
#
#        False       0.90      1.00      0.94     16175
#         True       0.23      0.01      0.02      1896
#
#    micro avg       0.89      0.89      0.89     18071
#    macro avg       0.56      0.50      0.48     18071
# weighted avg       0.83      0.89      0.85     18071

# %%
ecigdf.shape
# Out:
# (54758, 38)

# %%
## With upsampling the minority class
getModel(ecigdf, classImballanceUpSample)
# Out:
# Predictors:  37
# label:  label
# Label Encoding.
# Train Test Split:
# (36687, 37) (18071, 37) (36687, 1) (18071, 1)
# Before Class Imballance Treatment:
# False    32823
# True      3864
# Name: label, dtype: int64
# After Class Imballance Treatment:
# True     32823
# False    32823
# Name: label, dtype: int64
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Accuracy :  0.8778152841569365
#               precision    recall  f1-score   support
#
#        False       0.90      0.97      0.93     16175
#         True       0.22      0.06      0.10      1896
#
#    micro avg       0.88      0.88      0.88     18071
#    macro avg       0.56      0.52      0.52     18071
# weighted avg       0.83      0.88      0.85     18071

# %%
## With downsampling the majority class
getModel(ecigdf, classImballanceDownSample)
# Out:
# Predictors:  37
# label:  label
# Label Encoding.
# Train Test Split:
# (3859, 37) (1901, 37) (3859, 1) (1901, 1)
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Before Class Imballance Treatment:
# True    3859
# Name: label, dtype: int64
# After Class Imballance Treatment:
# True    3859
# Name: label, dtype: int64
# Accuracy :  1.0
#               precision    recall  f1-score   support
#
#         True       1.00      1.00      1.00      1901
#
#    micro avg       1.00      1.00      1.00      1901
#    macro avg       1.00      1.00      1.00      1901
# weighted avg       1.00      1.00      1.00      1901

# %%
## Use rfc weight paramter to ballance “balanced”, “balanced_subsample”
weights = {True:4,False:1}
getModel(ecigdf, ballanceClasses = None, rfcBalance = weights)
# Out:
# Predictors:  37
# label:  label
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Label Encoding.
# Train Test Split:
# (3859, 37) (1901, 37) (3859, 1) (1901, 1)
# RandomForestClassifier(bootstrap=True, class_weight={True: 4, False: 1},
#             criterion='gini', max_depth=None, max_features='auto',
#             max_leaf_nodes=None, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators='warn', n_jobs=None, oob_score=False,
#             random_state=None, verbose=0, warm_start=False)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-e76a4b5731a6> in <module>
#       1 ## Use rfc weight paramter to ballance “balanced”, “balanced_subsample”
#       2 weights = {True:4,False:1}
# ----> 3 getModel(ecigdf, ballanceClasses = None, rfcBalance = weights)
#
# <ipython-input-23-487822d889af> in getModel(df, ballanceClasses, rfcBalance)
#      38
#      39     #clf = rfc()
# ---> 40     clf.fit(X_train, y_train.values.ravel())
#      41     y_pred = clf.predict(X_test)
#      42     print("Accuracy : ", np.sum(y_test[ycols[0]].values==y_pred).astype(float)/len(y_test) )
#
# ~/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     276         self.n_outputs_ = y.shape[1]
#     277
# --> 278         y, expanded_class_weight = self._validate_y_class_weight(y)
#     279
#     280         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/ensemble/forest.py in _validate_y_class_weight(self, y)
#     519                     class_weight = self.class_weight
#     520                 expanded_class_weight = compute_sample_weight(class_weight,
# --> 521                                                               y_original)
#     522
#     523         return y, expanded_class_weight
#
# ~/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/utils/class_weight.py in compute_sample_weight(class_weight, y, indices)
#     162             weight_k = compute_class_weight(class_weight_k,
#     163                                             classes_full,
# --> 164                                             y_full)
#     165
#     166         weight_k = weight_k[np.searchsorted(classes_full, y_full)]
#
# ~/miniconda3/envs/ds_basic/lib/python3.7/site-packages/sklearn/utils/class_weight.py in compute_class_weight(class_weight, classes, y)
#      64             i = np.searchsorted(classes, c)
#      65             if i >= len(classes) or classes[i] != c:
# ---> 66                 raise ValueError("Class label {} not present.".format(c))
#      67             else:
#      68                 weight[i] = class_weight[c]
#
# ValueError: Class label False not present.

# %% [markdown]
# ### Weights argument is not solving the imballance problem.

# %% [markdown]
# ### Some Rules of Thumb for Imballance
#
#     - Consider testing under-sampling when you have an a lot data (tens- or hundreds of thousands of instances or more)
#     - Consider testing over-sampling when you don’t have a lot of data (tens of thousands of records or less)
#     - Consider testing random and non-random (e.g. stratified) sampling schemes.
#     - Consider testing different resampled ratios (e.g. you don’t have to target a 1:1 ratio in a binary classification problem, try other ratios)

# %% [markdown]
# ### ALso try SMOTE

# %%
print(ecigdf.shape)
print(ecigdf.columns)
ecigdf.head()
# Out:
# (54758, 38)
# Index(['COMPUTED PHYSICAL HEALTH STATUS', 'COMPUTED MENTAL HEALTH STATUS',
#        'HIGH BLOOD PRESSURE CALCULATED VARIABLE',
#        'CHOLESTEROL CHECKED CALCULATED VARIABLE',
#        'HIGH CHOLESTEROL CALCULATED VARIABLE',
#        'LIFETIME ASTHMA CALCULATED VARIABLE',
#        'CURRENT ASTHMA CALCULATED VARIABLE', 'COMPUTED ASTHMA STATUS',
#        'COMPUTED PREFERRED RACE', 'CALCULATED NON-HISPANIC RACE INCLUDING M',
#        'COMPUTED RACE-ETHNICITY GROUPING',
#        'COMPUTED NON-HISPANIC WHITES/ALL OTHERS',
#        'COMPUTED FIVE LEVEL RACE/ETHNICITY CATEG',
#        'COMPUTED RACE GROUPS USED FOR INTERNET P', 'COMPUTED HEIGHT IN INCHES',
#        'COMPUTED HEIGHT IN METERS', 'COMPUTED WEIGHT IN KILOGRAMS',
#        'COMPUTED BODY MASS INDEX', 'COMPUTED BODY MASS INDEX CATEGORIES',
#        'OVERWEIGHT OR OBESE CALCULATED VARIABLE',
#        'COMPUTED NUMBER OF CHILDREN IN HOUSEHOLD',
#        'COMPUTED LEVEL OF EDUCATION COMPLETED CA',
#        'COMPUTED INCOME CATEGORIES', 'COMPUTED DRINK-OCCASIONS-PER-DAY',
#        'BINGE DRINKING CALCULATED VARIABLE',
#        'COMPUTED NUMBER OF DRINKS OF ALCOHOL BEV',
#        'HEAVY ALCOHOL CONSUMPTION  CALCULATED VA',
#        'COMPUTED FRUIT JUICE INTAKE IN TIMES PER',
#        'COMPUTED FRUIT INTAKE IN TIMES PER DAY',
#        'COMPUTED DARK GREEN VEGETABLE INTAKE IN',
#        'COMPUTED POTATO SERVINGS PER DAY',
#        'COMPUTED OTHER VEGETABLE INTAKE IN TIMES',
#        '150 MINUTE PHYSICAL ACTIVITY CALCULATED',
#        '300 MINUTE PHYSICAL ACTIVITY CALCULATED',
#        'FLU SHOT CALCULATED VARIABLE',
#        'PNEUMONIA VACCINATION CALCULATED VARIABL',
#        'EVER BEEN TESTED FOR HIV CALCULATED VARI', 'label'],
#       dtype='object')
#             COMPUTED PHYSICAL HEALTH STATUS  \
# 5   1-13 days when physical health not good
# 26  Zero days when physical health not good
# 27  1-13 days when physical health not good
# 29  1-13 days when physical health not good
# 34  Zero days when physical health not good
#
#             COMPUTED MENTAL HEALTH STATUS  \
# 5   Zero days when mental health not good
# 26  Zero days when mental health not good
# 27  1-13 days when mental health not good
# 29  Zero days when mental health not good
# 34   14+ days when mental health not good
#
#    HIGH BLOOD PRESSURE CALCULATED VARIABLE  \
# 5                                      Yes
# 26                                      No
# 27                                      No
# 29                                      No
# 34                                      No
#
#              CHOLESTEROL CHECKED CALCULATED VARIABLE  \
# 5            Had cholesterol checked in past 5 years
# 26                Have never had cholesterol checked
# 27           Had cholesterol checked in past 5 years
# 29  Did not have cholesterol checked in past 5 years
# 34            Don�t know/Not Sure Or Refused/Missing
#
#    HIGH CHOLESTEROL CALCULATED VARIABLE LIFETIME ASTHMA CALCULATED VARIABLE  \
# 5                                    No                                  No
# 26                              Missing                                  No
# 27                                  Yes                                  No
# 29                                   No                                  No
# 34                              Missing                                  No
#
#    CURRENT ASTHMA CALCULATED VARIABLE COMPUTED ASTHMA STATUS  \
# 5                                  No                  Never
# 26                                 No                  Never
# 27                                 No                  Never
# 29                                 No                  Never
# 34                                 No                  Never
#
#    COMPUTED PREFERRED RACE CALCULATED NON-HISPANIC RACE INCLUDING M  ...    \
# 5                    White                               White only  ...
# 26                   White                               White only  ...
# 27                   White                               White only  ...
# 29                   White                               White only  ...
# 34                   White                               White only  ...
#
#    COMPUTED FRUIT INTAKE IN TIMES PER DAY  \
# 5                                     2.0
# 26                                  100.0
# 27                                   29.0
# 29                                   57.0
# 34                                   67.0
#
#    COMPUTED DARK GREEN VEGETABLE INTAKE IN COMPUTED POTATO SERVINGS PER DAY  \
# 5                                     29.0                             43.0
# 26                                   100.0                             43.0
# 27                                    33.0                              7.0
# 29                                    43.0                             43.0
# 34                                    17.0                             67.0
#
#    COMPUTED OTHER VEGETABLE INTAKE IN TIMES  \
# 5                                     100.0
# 26                                    100.0
# 27                                     23.0
# 29                                    100.0
# 34                                     50.0
#
#               150 MINUTE PHYSICAL ACTIVITY CALCULATED  \
# 5   1-149 minutes  (or vigorous equivalent minutes...
# 26  1-149 minutes  (or vigorous equivalent minutes...
# 27  150+ minutes (or vigorous equivalent minutes) ...
# 29  150+ minutes (or vigorous equivalent minutes) ...
# 34  0 minutes (or vigorous equivalent minutes) of ...
#
#               300 MINUTE PHYSICAL ACTIVITY CALCULATED  \
# 5   1-300 minutes  (or vigorous equivalent minutes...
# 26  1-300 minutes  (or vigorous equivalent minutes...
# 27  301+ minutes  (or vigorous equivalent minutes)...
# 29  1-300 minutes  (or vigorous equivalent minutes...
# 34  0 minutes  (or vigorous equivalent minutes) of...
#
#     FLU SHOT CALCULATED VARIABLE PNEUMONIA VACCINATION CALCULATED VARIABL  \
# 5                            Yes                                       No
# 26              Age Less Than 65                         Age Less Than 65
# 27                            No                                      Yes
# 29              Age Less Than 65                         Age Less Than 65
# 34              Age Less Than 65                         Age Less Than 65
#
#    EVER BEEN TESTED FOR HIV CALCULATED VARI  label
# 5                                        No  False
# 26                                      Yes  False
# 27                                       No  False
# 29                                       No  False
# 34                                       No  False
#
# [5 rows x 38 columns]

# %%
ecigdf.dtypes
# Out:
# COMPUTED PHYSICAL HEALTH STATUS              object
# COMPUTED MENTAL HEALTH STATUS                object
# HIGH BLOOD PRESSURE CALCULATED VARIABLE      object
# CHOLESTEROL CHECKED CALCULATED VARIABLE      object
# HIGH CHOLESTEROL CALCULATED VARIABLE         object
# LIFETIME ASTHMA CALCULATED VARIABLE          object
# CURRENT ASTHMA CALCULATED VARIABLE           object
# COMPUTED ASTHMA STATUS                       object
# COMPUTED PREFERRED RACE                      object
# CALCULATED NON-HISPANIC RACE INCLUDING M     object
# COMPUTED RACE-ETHNICITY GROUPING             object
# COMPUTED NON-HISPANIC WHITES/ALL OTHERS      object
# COMPUTED FIVE LEVEL RACE/ETHNICITY CATEG     object
# COMPUTED RACE GROUPS USED FOR INTERNET P     object
# COMPUTED HEIGHT IN INCHES                    object
# COMPUTED HEIGHT IN METERS                    object
# COMPUTED WEIGHT IN KILOGRAMS                float64
# COMPUTED BODY MASS INDEX                     object
# COMPUTED BODY MASS INDEX CATEGORIES          object
# OVERWEIGHT OR OBESE CALCULATED VARIABLE      object
# COMPUTED NUMBER OF CHILDREN IN HOUSEHOLD     object
# COMPUTED LEVEL OF EDUCATION COMPLETED CA     object
# COMPUTED INCOME CATEGORIES                   object
# COMPUTED DRINK-OCCASIONS-PER-DAY             object
# BINGE DRINKING CALCULATED VARIABLE           object
# COMPUTED NUMBER OF DRINKS OF ALCOHOL BEV     object
# HEAVY ALCOHOL CONSUMPTION  CALCULATED VA     object
# COMPUTED FRUIT JUICE INTAKE IN TIMES PER    float64
# COMPUTED FRUIT INTAKE IN TIMES PER DAY      float64
# COMPUTED DARK GREEN VEGETABLE INTAKE IN     float64
# COMPUTED POTATO SERVINGS PER DAY            float64
# COMPUTED OTHER VEGETABLE INTAKE IN TIMES    float64
# 150 MINUTE PHYSICAL ACTIVITY CALCULATED      object
# 300 MINUTE PHYSICAL ACTIVITY CALCULATED      object
# FLU SHOT CALCULATED VARIABLE                 object
# PNEUMONIA VACCINATION CALCULATED VARIABL     object
# EVER BEEN TESTED FOR HIV CALCULATED VARI     object
# label                                          bool
# dtype: object

# %%
ecigdf.to_csv(dataDirectory+'df_balanced.csv')

# %%
### Plot distributions

# %%
import matplotlib.pyplot as plt
import pylab as pl
import seaborn as sns
# %matplotlib inline

tmp = ecigdf

# %%
def reject_outliers(data, m=2):
    return data[abs(data - np.mean(data)) < m * np.std(data)]

# %%
colname = 'COMPUTED FRUIT INTAKE IN TIMES PER DAY'
cat = tmp[[colname, 'label']]
ymax = max(reject_outliers(cat[colname], 3))
ymin = min(reject_outliers(cat[colname], 3))
boxpl = sns.boxplot(data=cat, x='label', y=colname)
ax = boxpl.axes
ax.set_ylim(ymin,300)
# Out:
# (0.0, 300)

# %%
colname = 'COMPUTED PHYSICAL HEALTH STATUS'
cat = tmp[[colname, 'label']].groupby([colname, 'label']).size().reset_index()
cat.columns = [colname, 'label', 'count']
sns.catplot(x=colname, y='count', hue="label", data=cat, kind="bar").set_xticklabels(rotation=30)
# cat.head()
# set(cat['COMPUTED PHYSICAL HEALTH STATUS'])

# %%
print(ymin, ymax)
# Out:
# 0.0 500.0

# %%
cat = tmp[[i, 'label']].groupby([i, 'label']).size().reset_index()
cat.columns = [i, 'label', 'count']
cat_tot = cat.groupby('label').sum().reset_index()
cat = cat.merge(cat_tot, how='left', left_on='label', right_on='label')
cat['ratioCount'] = cat.count_x / cat.count_y
cat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-44342d984276> in <module>
# ----> 1 cat = tmp[[i, 'label']].groupby([i, 'label']).size().reset_index()
#       2 cat.columns = [i, 'label', 'count']
#       3 cat_tot = cat.groupby('label').sum().reset_index()
#       4 cat = cat.merge(cat_tot, how='left', left_on='label', right_on='label')
#       5 cat['ratioCount'] = cat.count_x / cat.count_y
#
# NameError: name 'i' is not defined

# %%
tmp = ecigdf
colnum=0
for i in tmp.columns[:-1]:
    if (tmp[i].dtypes=='float64'):
        ymax = max(reject_outliers(tmp[i], 3))
        ymin = min(reject_outliers(tmp[i], 3))
        sns.catplot(data=tmp, x='label', y=i, kind='box')
        plt.ylim(ymin, ymax)
        plt.savefig(str(colnum)+'.png')
    else:
        cat = tmp[[i, 'label']].groupby([i, 'label']).size().reset_index()
        cat.columns = [i, 'label', 'count']
#         cat['count'] = (cat['count']-cat['count'].mean())/cat['count'].std()
#         cat['count'] = np.log10(cat['count'])
        cat_tot = cat.groupby('label').sum().reset_index()
        cat = cat.merge(cat_tot, how='left', left_on='label', right_on='label')
        cat['ratioCount'] = cat.count_x / cat.count_y
        sns.catplot(x=i, y='ratioCount', hue="label", data=cat, kind="bar").set_xticklabels(rotation=30)
        plt.savefig(str(colnum)+'.png')
    colnum += 1
# Out:
# /home/tanya/miniconda3/envs/ds_basic/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
for i in range(len(ecigdf.columns[:-1])):
    print()

# %%
comDF.columns
# Out:
# Index(['COMPUTED PHYSICAL HEALTH STATUS', 'COMPUTED MENTAL HEALTH STATUS',
#        'HIGH BLOOD PRESSURE CALCULATED VARIABLE',
#        'CHOLESTEROL CHECKED CALCULATED VARIABLE',
#        'HIGH CHOLESTEROL CALCULATED VARIABLE',
#        'LIFETIME ASTHMA CALCULATED VARIABLE',
#        'CURRENT ASTHMA CALCULATED VARIABLE', 'COMPUTED ASTHMA STATUS',
#        'COMPUTED PREFERRED RACE', 'CALCULATED NON-HISPANIC RACE INCLUDING M',
#        'COMPUTED RACE-ETHNICITY GROUPING',
#        'COMPUTED NON-HISPANIC WHITES/ALL OTHERS',
#        'COMPUTED FIVE LEVEL RACE/ETHNICITY CATEG',
#        'COMPUTED RACE GROUPS USED FOR INTERNET P', 'COMPUTED HEIGHT IN INCHES',
#        'COMPUTED HEIGHT IN METERS', 'COMPUTED WEIGHT IN KILOGRAMS',
#        'COMPUTED BODY MASS INDEX', 'COMPUTED BODY MASS INDEX CATEGORIES',
#        'OVERWEIGHT OR OBESE CALCULATED VARIABLE',
#        'COMPUTED NUMBER OF CHILDREN IN HOUSEHOLD',
#        'COMPUTED LEVEL OF EDUCATION COMPLETED CA',
#        'COMPUTED INCOME CATEGORIES', 'COMPUTED SMOKING STATUS',
#        'CURRENT SMOKING CALCULATED VARIABLE',
#        'COMPUTED E-CIGARETTE USER STATUS',
#        'CURRENT E-CIGARETTE USER CALCULATED VARI',
#        'COMPUTED DRINK-OCCASIONS-PER-DAY',
#        'BINGE DRINKING CALCULATED VARIABLE',
#        'COMPUTED NUMBER OF DRINKS OF ALCOHOL BEV',
#        'HEAVY ALCOHOL CONSUMPTION  CALCULATED VA',
#        'COMPUTED FRUIT JUICE INTAKE IN TIMES PER',
#        'COMPUTED FRUIT INTAKE IN TIMES PER DAY',
#        'COMPUTED DARK GREEN VEGETABLE INTAKE IN',
#        'COMPUTED POTATO SERVINGS PER DAY',
#        'COMPUTED OTHER VEGETABLE INTAKE IN TIMES',
#        '150 MINUTE PHYSICAL ACTIVITY CALCULATED',
#        '300 MINUTE PHYSICAL ACTIVITY CALCULATED',
#        'FLU SHOT CALCULATED VARIABLE',
#        'PNEUMONIA VACCINATION CALCULATED VARIABL',
#        'EVER BEEN TESTED FOR HIV CALCULATED VARI'],
#       dtype='object')

# %%
print(comDF.shape)
print(ecigdf.shape)
# Out:
# (379592, 41)
# (54758, 38)

# %%
print(set(comDF['CURRENT SMOKING CALCULATED VARIABLE']))
print(set(comDF['COMPUTED SMOKING STATUS']))
print(set(comDF['CURRENT E-CIGARETTE USER CALCULATED VARI']))
print(set(comDF['COMPUTED E-CIGARETTE USER STATUS']))
# Out:
# {'Yes', 'Don�t know/Refused/Missing', 'No'}
# {'Current smoker - now smokes some days', 'Current smoker - now smokes every day', 'Former smoker', 'Never smoked', 'Don�t know/Refused/Missing'}
# {'Don�t know/Refused/Missing', 'Current E-cigarette user', 'Not currently using E-cigarettes'}
# {'Former E-cigarette user', 'Never used E-cigarettes', 'Current E-cigarette user - uses every day', 'Don�t know/Refused/Missing', 'Current E-cigarette user - uses some days'}

# %%
sm_cols = ['CURRENT SMOKING CALCULATED VARIABLE','COMPUTED SMOKING STATUS','CURRENT E-CIGARETTE USER CALCULATED VARI','COMPUTED E-CIGARETTE USER STATUS']
dt = comDF
dt = dt.replace('Don�t know/Refused/Missing', np.nan)
dt = dt[dt['CURRENT SMOKING CALCULATED VARIABLE']!='nan']
# dt['label'] = 
print(dt[sm_cols].describe())
dt[sm_cols].head(30)
# Out:
#        CURRENT SMOKING CALCULATED VARIABLE COMPUTED SMOKING STATUS  \
# count                               377922                  377922
# unique                                   2                       4
# top                                     No            Never smoked
# freq                                322389                  214955
#
#        CURRENT E-CIGARETTE USER CALCULATED VARI  \
# count                                    379065
# unique                                        2
# top            Not currently using E-cigarettes
# freq                                     366784
#
#        COMPUTED E-CIGARETTE USER STATUS
# count                            379065
# unique                                4
# top             Never used E-cigarettes
# freq                             318979
#    CURRENT SMOKING CALCULATED VARIABLE                COMPUTED SMOKING STATUS  \
# 0                                   No                           Never smoked
# 1                                   No                           Never smoked
# 2                                   No                           Never smoked
# 4                                   No                          Former smoker
# 5                                  Yes  Current smoker - now smokes every day
# 6                                   No                           Never smoked
# 8                                   No                          Former smoker
# 9                                   No                          Former smoker
# 10                                  No                           Never smoked
# 11                                  No                           Never smoked
# 12                                  No                           Never smoked
# 13                                  No                           Never smoked
# 14                                  No                           Never smoked
# 15                                  No                           Never smoked
# 16                                  No                           Never smoked
# 18                                  No                           Never smoked
# 20                                 Yes  Current smoker - now smokes every day
# 21                                  No                           Never smoked
# 23                                  No                          Former smoker
# 24                                  No                           Never smoked
# 25                                  No                           Never smoked
# 26                                 Yes  Current smoker - now smokes every day
# 27                                 Yes  Current smoker - now smokes every day
# 28                                  No                           Never smoked
# 29                                 Yes  Current smoker - now smokes every day
# 30                                  No                          Former smoker
# 32                                  No                           Never smoked
# 33                                  No                          Former smoker
# 34                                 Yes  Current smoker - now smokes every day
# 35                                  No                           Never smoked
#
#    CURRENT E-CIGARETTE USER CALCULATED VARI  \
# 0          Not currently using E-cigarettes
# 1          Not currently using E-cigarettes
# 2          Not currently using E-cigarettes
# 4          Not currently using E-cigarettes
# 5          Not currently using E-cigarettes
# 6          Not currently using E-cigarettes
# 8          Not currently using E-cigarettes
# 9          Not currently using E-cigarettes
# 10         Not currently using E-cigarettes
# 11         Not currently using E-cigarettes
# 12         Not currently using E-cigarettes
# 13         Not currently using E-cigarettes
# 14         Not currently using E-cigarettes
# 15         Not currently using E-cigarettes
# 16         Not currently using E-cigarettes
# 18         Not currently using E-cigarettes
# 20                 Current E-cigarette user
# 21         Not currently using E-cigarettes
# 23         Not currently using E-cigarettes
# 24         Not currently using E-cigarettes
# 25         Not currently using E-cigarettes
# 26         Not currently using E-cigarettes
# 27         Not currently using E-cigarettes
# 28         Not currently using E-cigarettes
# 29         Not currently using E-cigarettes
# 30         Not currently using E-cigarettes
# 32         Not currently using E-cigarettes
# 33         Not currently using E-cigarettes
# 34         Not currently using E-cigarettes
# 35         Not currently using E-cigarettes
#
#              COMPUTED E-CIGARETTE USER STATUS
# 0                     Never used E-cigarettes
# 1                     Never used E-cigarettes
# 2                     Never used E-cigarettes
# 4                     Never used E-cigarettes
# 5                     Never used E-cigarettes
# 6                     Never used E-cigarettes
# 8                     Never used E-cigarettes
# 9                     Never used E-cigarettes
# 10                    Never used E-cigarettes
# 11                    Never used E-cigarettes
# 12                    Never used E-cigarettes
# 13                    Never used E-cigarettes
# 14                    Never used E-cigarettes
# 15                    Never used E-cigarettes
# 16                    Never used E-cigarettes
# 18                    Never used E-cigarettes
# 20  Current E-cigarette user - uses some days
# 21                    Never used E-cigarettes
# 23                    Never used E-cigarettes
# 24                    Never used E-cigarettes
# 25                    Never used E-cigarettes
# 26                    Former E-cigarette user
# 27                    Former E-cigarette user
# 28                    Never used E-cigarettes
# 29                    Former E-cigarette user
# 30                    Never used E-cigarettes
# 32                    Never used E-cigarettes
# 33                    Never used E-cigarettes
# 34                    Former E-cigarette user
# 35                    Never used E-cigarettes

# %%
print(set(dt['CURRENT SMOKING CALCULATED VARIABLE']))
print(set(dt['COMPUTED SMOKING STATUS']))
print(set(dt['CURRENT E-CIGARETTE USER CALCULATED VARI']))
print(set(dt['COMPUTED E-CIGARETTE USER STATUS']))
# Out:
# {'Yes', nan, 'No'}
# {nan, 'Current smoker - now smokes some days', 'Current smoker - now smokes every day', 'Former smoker', 'Never smoked'}
# {nan, 'Current E-cigarette user', 'Not currently using E-cigarettes'}
# {nan, 'Former E-cigarette user', 'Never used E-cigarettes', 'Current E-cigarette user - uses every day', 'Current E-cigarette user - uses some days'}

# %%
[print(i) for i in df.columns]
# Out:
# STATE FIPS CODE
# FILE MONTH
# INTERVIEW DATE
# INTERVIEW MONTH
# INTERVIEW DAY
# INTERVIEW YEAR
# FINAL DISPOSITION
# ANNUAL SEQUENCE NUMBER
# PRIMARY SAMPLING UNIT
# CORRECT TELEPHONE NUMBER?
# PRIVATE RESIDENCE?
# DO YOU LIVE IN COLLEGE HOUSING?
# RESIDENT OF STATE
# CELLULAR TELEPHONE
# ARE YOU 18 YEARS OF AGE OR OLDER?
# NUMBER OF ADULTS IN HOUSEHOLD
# NUMBER OF ADULT MEN IN HOUSEHOLD
# NUMBER OF ADULT WOMEN IN HOUSEHOLD
# SAFE TIME TO TALK?
# CORRECT PHONE NUMBER?
# IS THIS A CELL TELEPHONE?
# ARE YOU 18 YEARS OF AGE OR OLDER?.1
# DO YOU LIVE IN A PRIVATE RESIDENCE?
# DO YOU LIVE IN COLLEGE HOUSING?.1
# DO YOU CURRENTLY LIVE IN  ____(STATE)___
# DO YOU ALSO HAVE A LANDLINE TELEPHONE?
# NUMBER OF ADULTS IN HOUSEHOLD.1
# GENERAL HEALTH
# NUMBER OF DAYS PHYSICAL HEALTH NOT GOOD
# NUMBER OF DAYS MENTAL HEALTH NOT GOOD
# POOR PHYSICAL OR MENTAL HEALTH
# HAVE ANY HEALTH CARE COVERAGE
# MULTIPLE HEALTH CARE PROFESSIONALS
# COULD NOT SEE DR. BECAUSE OF COST
# LENGTH OF TIME SINCE LAST ROUTINE CHECKU
# EVER TOLD BLOOD PRESSURE HIGH
# CURRENTLY TAKING BLOOD PRESSURE MEDICATI
# HOW LONG SINCE CHOLESTEROL CHECKED
# EVER TOLD BLOOD CHOLESTEROL HIGH
# CURRENTLY TAKING MEDICINE FOR HIGH CHOLE
# EVER DIAGNOSED WITH HEART ATTACK
# EVER DIAGNOSED WITH ANGINA OR CORONARY H
# EVER DIAGNOSED WITH A STROKE
# EVER TOLD HAD ASTHMA
# STILL HAVE ASTHMA
# (EVER TOLD) YOU HAD SKIN CANCER?
# (EVER TOLD) YOU HAD ANY OTHER TYPES OF C
# (EVER TOLD) YOU HAVE (COPD) CHRONIC OBST
# TOLD HAVE ARTHRITIS
# EVER TOLD YOU HAD A DEPRESSIVE DISORDER
# (EVER TOLD) YOU HAVE KIDNEY DISEASE?
# (EVER TOLD) YOU HAVE DIABETES
# AGE WHEN TOLD DIABETIC
# LIMITED BECAUSE OF JOINT SYMPTOMS
# DOES ARTHRITIS AFFECT WHETHER YOU WORK
# SOCIAL ACTIVITIES LIMITED BECAUSE OF JOI
# HOW BAD WAS JOINT PAIN
# RESPONDENTS SEX
# MARITAL STATUS
# EDUCATION LEVEL
# OWN OR RENT HOME
# HOUSEHOLD TELEPHONES
# RESIDENTIAL PHONES
# DO YOU HAVE A CELL PHONE FOR PERSONAL US
# ARE YOU A VETERAN
# EMPLOYMENT STATUS
# NUMBER OF CHILDREN IN HOUSEHOLD
# INCOME LEVEL
# INTERNET USE IN THE PAST 30 DAYS?
# REPORTED WEIGHT IN POUNDS
# REPORTED HEIGHT IN FEET AND INCHES
# PREGNANCY STATUS
# ARE YOU DEAF OR DO YOU HAVE SERIOUS DIFF
# BLIND OR DIFFICULTY SEEING
# DIFFICULTY CONCENTRATING OR REMEMBERING
# DIFFICULTY WALKING OR CLIMBING STAIRS
# DIFFICULTY DRESSING OR BATHING
# DIFFICULTY DOING ERRANDS ALONE
# SMOKED AT LEAST 100 CIGARETTES
# FREQUENCY OF DAYS NOW SMOKING
# STOPPED SMOKING IN PAST 12 MONTHS
# INTERVAL SINCE LAST SMOKED
# USE OF SMOKELESS TOBACCO PRODUCTS
# HAVE YOU EVER USED AN E-CIGARETTE OR OTH
# DO YOU NOW USE E-CIGARETTES, EVERY DAY,
# DAYS IN PAST 30 HAD ALCOHOLIC BEVERAGE
# AVG ALCOHOLIC DRINKS PER DAY IN PAST 30
# BINGE DRINKING
# MOST DRINKS ON SINGLE OCCASION PAST 30 D
# HOW MANY TIMES DID YOU EAT FRUIT?
# HOW MANY TIMES DID YOU DRINK 100 PERCENT
# HOW MANY TIMES DID YOU EAT DARK GREEN VE
# HOW OFTEN DO YOU EAT FRENCH FRIES OR FRI
# HOW OFTEN DO YOU EAT FRENCH FRIES OR FRI.1
# HOW OFTEN DO YOU EAT FRENCH FRIES OR FRI.2
# EXERCISE IN PAST 30 DAYS
# TYPE OF PHYSICAL ACTIVITY
# HOW MANY TIMES WALKING, RUNNING, JOGGING
# MINUTES OR HOURS WALKING, RUNNING, JOGGI
# OTHER TYPE OF PHYSICAL ACTIVITY GIVING M
# HOW MANY TIMES WALKING, RUNNING, JOGGING.1
# MINUTES OR HOURS WALKING, RUNNING, JOGGI.1
# HOW MANY TIMES DID YOU DO PHYSICAL ACTIV
# HOW OFTEN USE SEATBELTS IN CAR?
# ADULT FLU SHOT/SPRAY PAST 12 MOS
# WHEN RECEIVED MOST RECENT SEASONAL FLU S
# PNEUMONIA SHOT EVER
# HAVE YOU EVER HAD THE SHINGLES OR ZOSTER
# EVER TESTED HIV
# MONTH AND YEAR OF LAST HIV TEST
# DO ANY HIGH RISK SITUATIONS APPLY
# HAD A TEST FOR HIGH BLOOD SUGAR IN PAST
# EVER BEEN TOLD YOU HAVE PRE-DIABETES OR
# NOW TAKING INSULIN
# HOW OFTEN CHECK BLOOD FOR GLUCOSE
# HOW OFTEN CHECK FEET FOR SORES OR IRRITA
# TIMES SEEN HEALTH PROFESSIONAL FOR DIABE
# TIMES CHECKED FOR GLYCOSYLATED HEMOGLOBI
# TIMES FEET CHECK FOR SORES/IRRITATIONS
# LAST EYE EXAM WHERE PUPILS WERE DILATED
# EVER TOLD DIABETES HAS AFFECTED EYES
# EVER TAKEN CLASS IN MANAGING DIABETES
# DID YOU HAVE A COUGH?
# DID YOU COUGH UP PHLEGM?
# DID YOU HAVE SHORTNESS OF BREATH?
# HAVE YOU EVER BEEN GIVEN A BREATHING TES
# HOW MANY YEARS HAVE YOU SMOKED TOBACCO P
# OUTPATIENT REHAB AFTER HEART ATTACK HOSP
# OUTPATIENT REHAB AFTER HOSP STAY FOR STR
# TAKE ASPIRIN DAILY OR EVERY OTHER DAY
# HEALTH MAKES TAKING ASPIRIN UNSAFE
# TAKE ASPIRIN TO RELIEVE PAIN
# TAKE ASPIRIN TO REDUCE CHANCE OF HEART A
# TAKE ASPIRIN TO REDUCE CHANCE OF STROKE
# CHANGE EATING HABITS FOR BP?
# REDUCE SALT INTAKE TO LOWER BP?
# REDUCE ALCOHOL USE FOR BP?
# EXERCISING TO LOWER BP?
# HLTH CARE PRO EVER ADVISED CHANGE IN EAT
# HLTH CARE PRO EVER ADVISED USING LESS SA
# HLTH CARE PRO EVER ADVISED REDUCED ALCOH
# HLTH CARE PRO EVER ADVISED EXERCISE TO R
# HLTH CARE PRO EVER ADVISED MEDS TO REDUC
# TOLD HAD HIGH BP DURING 2+ VISITS TO HLT
# WHAT CAN YOU DO BECAUSE OF ARTHRITIS OR
# DR. SUGGEST LOSE WEIGHT FOR ARTHRITIS OR
# DR. SUGGEST USE OF PHYSICAL ACTIVITY OR
# EVER TAKEN CLASS IN MANAGING ARTHRITIS O
# AGE AT ASTHMA DIAGNOSIS
# ASTHMA DURING PAST 12 MONTHS
# EMERGENCY ASTHMA CARE DURING PAST 12 MON
# URGENT ASTHMA TREATMENT DURING PAST 12 M
# ROUTINE ASTHMA CARE DURING PAST 12 MONTH
# ACTIVITIES LIMITED DUE TO ASTHMA DURING
# ASTHMA SYMPTOMS DURING PAST 30 DAYS
# SLEEP DIFFICULTY DUE TO ASTHMA DURING PA
# DAYS USED PRESCRIBED PREVENTATIVE ASTHMA
# TIMES USED ASTHMA INHALER DURING AN ATTA
# HOW MANY DAYS HARD TO DO USUAL ACTIVITIE
# HOW MANY DAYS DEPRESSED IN PAST 30 DAYS
# HOW MANY DAYS FELT ANXIOUS IN PAST 30 DA
# HOW MANY DAYS FULL OF ENERGY IN PAST 30
# HOW MUCH TIME DO YOU SLEEP
# DAYS HAD TROUBLE WITH SLEEP
# OVER THE LAST 2 WEEKS, HOW MANY DAYS DID
# HAVE YOU EVER BEEN TOLD THAT YOU SNORE L
# HAS ANYONE EVER OBSERVED THAT YOU STOP B
# DO YOU HAVE MEDICARE?
# PRIMARY HEALTH INSURANCE COVERAGE
# DELAYED GETTING MEDICAL CARE
# DELAYED GETTING MEDICAL CARE OTHER RESPO
# WITHOUT HEALTH CARE COVERAGE PAST 12 MON
# TIME SINCE LAST HAD HEALTH CARE COVERAGE
# DOCTOR VISITS PAST 12 MONTHS
# COULD NOT GET MEDICINE DUE TO COST
# SATISFIED WITH CARE RECEIVED
# CURRENTLY HAVE HEALTH CARE BILLS
# ASKED DURING CHECKUP IF YOU DRINK ALCHOH
# ASKED IN PERSON OR BY FORM HOW MUCH YOU
# ASKED WHETHER YOU DRANK [5 FOR MEN /4 FO
# OFFERED ADVICE ABOUT WHAT LEVEL OF DRINK
# WERE YOU ADVISED TO REDUCE OR QUIT YOUR
# HOW MANY TYPES OF CANCER?
# AGE TOLD HAD CANCER
# TYPE OF CANCER
# CURRENTLY RECEIVING TREATMENT FOR CANCER
# WHAT TYPE OF DOCTOR PROVIDES MAJORITY OF
# DID YOU RECEIVE A SUMMARY OF CANCER TREA
# EVER RECEIVE INSTRUCTIONS FROM A DOCTOR
# INSTRUCTIONS WRITTEN OR PRINTED
# DID HEALTH INSURANCE PAY FOR ALL OF YOUR
# EVER DENIED INSURANCE COVERAGE BECAUSE O
# PARTICIPATE IN CLINICAL TRIAL AS PART OF
# CURRENTLY HAVE PHYSICAL PAIN FROM CANCER
# IS PAIN UNDER CONTROL?
# HOW OFTEN DID YOU DRINK REGULAR SODA OR
# HOW OFTEN DID YOU DRINK SUGAR-SWEETENED
# WATCHING SODIUM OR SALT INTAKE
# DOCTOR ADVISED REDUCED SODIUM/SALT INTAK
# DURING THE PAST 30 DAYS, ON HOW MANY DAY
# DURING THE PAST 30 DAYS, HOW DID YOU PRI
# RSNMRJNA
# DID YOU DO ANYTHING TO KEEP FROM GETTING
# WHAT DID YOU DO TO KEEP YOU FROM GETTING
# WHAT WAS MAIN REASON FOR NOT DOING ANYTH
# WHERE DID YOU GET YOUR LAST FLU SHOT/VAC
# EVER HAD THE HPV VACCINATION?
# NUMBER OF HPV SHOTS RECEIVED
# RECEIVED TETANUS SHOT SINCE 2005?
# HOW OLD WHEN YOU FIRST STARTED SMOKING?
# HOW OLD WHEN YOU LAST SMOKED?
# ON AVERAGE, HOW MANY CIGARETTES DO YOU S
# DID YOU HAVE A CT OR CAT SCAN?
# PROVIDED REGULAR CARE FOR FAMILY OR FRIE
# RELATIONSHIP OF PERSON TO WHOM YOU ARE G
# HOW LONG PROVIDED CARE FOR PERSON.
# HOW MANY HOURS DO YOU PROVIDE CARE FOR P
# WHAT IS THE MAJOR HEALTH PROBLEM, ILLNES
# MANAGED PERSONAL CARE
# MANAGED HOUSEHOLD TASKS
# WHICH SUPPORT DO YOU MOST NEED THAT YOU
# DO YOU EXPECT TO HAVE A RELATIVE YOU WIL
# HAVE YOU EXPERIENCED CONFUSION OR MEMORY
# GIVEN UP DAY-TO-DAY CHORES DUE TO CONFUS
# NEED ASSISTANCE WITH DAY-TO_DAY ACTIVITI
# WHEN YOU NEED HELP WITH DAY-TO-DAY ACTIV
# DOES CONFUSION OR MEMORY LOSS INTERFERE
# HAVE YOU DISCUSSED YOUR CONFUSION OR MEM
# HOW OFTEN GET EMOTIONAL SUPPORT NEEDED
# SATISFACTION WITH LIFE
# WERE YOU NOT ABLE TO PAY YOUR BILLS?
# HOW MANY TIMES HAVE YOU MOVED?
# NEIGHBORHOOD SAFE FROM CRIME
# NO MONEY FOR FOOD?
# NO MONEY FOR BALANCED MEALS?
# HOW DO YOUR FINANCES USUALLY WORK OUT AT
# HOW OFTEN HAVE YOU FELT THIS KIND OF STR
# SEXUAL ORIENTATION OR GENDER IDENTITY
# DO YOU CONSIDER YOURSELF TO BE TRANSGEND
# ANY FIREARMS IN HOME
# ANY FIREARMS LOADED
# ANY LOADED FIREARMS ALSO UNLOCKED
# GENDER OF CHILD
# RELATIONSHIP TO CHILD
# HLTH PRO EVER SAID CHILD HAS ASTHMA
# CHILD STILL HAVE ASTHMA?
# QUESTIONNAIRE VERSION IDENTIFIER
# LANGUAGE IDENTIFIER
# METROPOLITAN STATUS CODE
# SAMPLE DESIGN STRATIFICATION VARIABLE
# STRATUM WEIGHT
# RAW WEIGHTING FACTOR USED IN RAKING
# DESIGN WEIGHT USED IN RAKING
# IMPUTED RACE/ETHNICITY VALUE
# CHILD HISPANIC, LATINO/A, OR SPANISH ORI
# CHILD NON-HISPANIC RACE INCLUDING MULTIR
# PREFERRED CHILD RACE CATEGORIES
# FINAL CHILD WEIGHT: LAND-LINE AND CELL-P
# DUAL PHONE USE CATEGORIES
# DUAL PHONE USE CORRECTION FACTOR
# TRUNCATED DESIGN WEIGHT USED IN ADULT CO
# FINAL WEIGHT: LAND-LINE AND CELL-PHONE D
# ADULTS WITH GOOD OR BETTER HEALTH
# COMPUTED PHYSICAL HEALTH STATUS
# COMPUTED MENTAL HEALTH STATUS
# RESPONDENTS AGED 18-64 WITH HEALTH CARE
# HIGH BLOOD PRESSURE CALCULATED VARIABLE
# CHOLESTEROL CHECKED CALCULATED VARIABLE
# HIGH CHOLESTEROL CALCULATED VARIABLE
# RESPONDENTS THAT HAVE EVER REPORTED HAVI
# LIFETIME ASTHMA CALCULATED VARIABLE
# CURRENT ASTHMA CALCULATED VARIABLE
# COMPUTED ASTHMA STATUS
# RESPONDENTS DIAGNOSED WITH ARTHRITIS
# LIMITED USUAL ACTIVITIES
# LIMITED WORK ACTIVITIES
# LIMITED SOCIAL ACTIVITIES
# COMPUTED PREFERRED RACE
# CALCULATED NON-HISPANIC RACE INCLUDING M
# HISPANIC, LATINO/A, OR SPANISH ORIGIN CA
# COMPUTED RACE-ETHNICITY GROUPING
# COMPUTED NON-HISPANIC WHITES/ALL OTHERS
# COMPUTED FIVE LEVEL RACE/ETHNICITY CATEG
# COMPUTED RACE GROUPS USED FOR INTERNET P
# REPORTED AGE IN FIVE-YEAR AGE CATEGORIES
# REPORTED AGE IN TWO AGE GROUPS CALCULATE
# IMPUTED AGE VALUE COLLAPSED ABOVE 80
# IMPUTED AGE IN SIX GROUPS
# COMPUTED HEIGHT IN INCHES
# COMPUTED HEIGHT IN METERS
# COMPUTED WEIGHT IN KILOGRAMS
# COMPUTED BODY MASS INDEX
# COMPUTED BODY MASS INDEX CATEGORIES
# OVERWEIGHT OR OBESE CALCULATED VARIABLE
# COMPUTED NUMBER OF CHILDREN IN HOUSEHOLD
# COMPUTED LEVEL OF EDUCATION COMPLETED CA
# COMPUTED INCOME CATEGORIES
# COMPUTED SMOKING STATUS
# CURRENT SMOKING CALCULATED VARIABLE
# COMPUTED E-CIGARETTE USER STATUS
# CURRENT E-CIGARETTE USER CALCULATED VARI
# DRINK ANY ALCOHOLIC BEVERAGES IN PAST 30
# COMPUTED DRINK-OCCASIONS-PER-DAY
# BINGE DRINKING CALCULATED VARIABLE
# COMPUTED NUMBER OF DRINKS OF ALCOHOL BEV
# HEAVY ALCOHOL CONSUMPTION  CALCULATED VA
# COMPUTED FRUIT JUICE INTAKE IN TIMES PER
# COMPUTED FRUIT INTAKE IN TIMES PER DAY
# COMPUTED DARK GREEN VEGETABLE INTAKE IN
# FRENCH FRY INTAKE IN TIMES PER DAY
# COMPUTED POTATO SERVINGS PER DAY
# COMPUTED OTHER VEGETABLE INTAKE IN TIMES
# THE NUMBER OF MISSING FRUIT RESPONSES
# THE NUMBER OF MISSING VEGETABLE RESPONSE
# MISSING ANY FRUIT RESPONSES
# MISSING ANY VEGETABLE RESPONSES
# TOTAL FRUITS CONSUMED PER DAY
# TOTAL VEGETABLES CONSUMED PER DAY
# CONSUME FRUIT 1 OR MORE TIMES PER DAY
# CONSUME VEGETABLES 1 OR MORE TIMES PER D
# REPORTED CONSUMING FRUIT >16/DAY
# REPORTED CONSUMING VEGETABLES >23/DAY
# FRUIT EXCLUSION FROM ANALYSES
# VEGETABLE EXCLUSION FROM ANALYSES
# LEISURE TIME PHYSICAL ACTIVITY CALCULATE
# ACTIVITY MET VALUE FOR FIRST ACTIVITY
# ACTIVITY MET VALUE FOR SECOND ACTIVITY
# ESTIMATED AGE-GENDER SPECIFIC MAXIMUM OX
# ESTIMATED FUNCTIONAL CAPACITY
# ESTIMATED ACTIVITY INTENSITY FOR FIRST A
# ESTIMATED ACTIVITY INTENSITY FOR SECOND
# MINUTES OF FIRST ACTIVITY
# MINUTES OF SECOND ACTIVITY
# PHYSICAL ACTIVITY FREQUENCY PER WEEK FOR
# PHYSICAL ACTIVITY FREQUENCY PER WEEK FOR.1
# MINUTES OF PHYSICAL ACTIVITY PER WEEK FO
# MINUTES OF PHYSICAL ACTIVITY PER WEEK FO.1
# STRENGTH ACTIVITY FREQUENCY PER WEEK
# MISSING PHYSICAL ACTIVITY DATA
# MINUTES OF PHYSICAL ACTIVITY PER WEEK FO.2
# MINUTES OF PHYSICAL ACTIVITY PER WEEK FO.3
# MINUTES OF TOTAL PHYSICAL ACTIVITY PER W
# MINUTES OF VIGOROUS PHYSICAL ACTIVITY PE
# MINUTES OF VIGOROUSPHYSICAL ACTIVITY PER
# MINUTES OF TOTAL VIGOROUS PHYSICAL ACTIV
# PHYSICAL ACTIVITY CATEGORIES
# PHYSICAL ACTIVITY INDEX
# 150 MINUTE PHYSICAL ACTIVITY CALCULATED
# 300 MINUTE PHYSICAL ACTIVITY CALCULATED
# 300 MINUTE PHYSICAL ACTIVITY 2-LEVEL CAL
# MUSCLE STRENGTHENING RECOMMENDATION
# AEROBIC AND STRENGTHENING GUIDELINE
# AEROBIC AND STRENGTHENING (2-LEVEL)
# ALWAYS OR NEARLY ALWAYS WEAR SEAT BELTS
# ALWAYS WEAR SEAT BELTS
# FLU SHOT CALCULATED VARIABLE
# PNEUMONIA VACCINATION CALCULATED VARIABL
# EVER BEEN TESTED FOR HIV CALCULATED VARI
# ADLTCHLD
# AGE
# CALLBACK
# CALLBCKZ
# CHILDAGE
# NAMTRIBE
# ORACE3
# PRECALL
# RCSBRAC2
# RSPSTAT1
# SECSCRFL
# WDHOWOFT
# WDSHARE
# WDUSENOW
# _DENSTR2
# _IMPAGE
# _IMPCAGE
# _IMPCRAC
# _IMPCSEX
# _IMPEDUC
# _IMPHOME
# _IMPMRTL
# _IMPNPH
# _IMPSEX
# _M_RACE
# _URBNRRL
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
