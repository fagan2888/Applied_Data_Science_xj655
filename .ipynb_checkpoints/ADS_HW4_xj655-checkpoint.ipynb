# %% [markdown]
# # ADS Homework #4
# ### Author: Xiao(Robin) Jing

# %% [markdown]
# ### Problem 1 - Markov Processes (40 points)

# %% [markdown]
# In class, we walked through an example of a rat moving between subway tracks. While any New Yorker knows that this is doubtlessly a very real urban example, in the real world, unless you have an oddly musophilic boss, you likely will be tasked with more human-centric analyses. Let's dig into an example of people moving throughout a subset of 5 Brooklyn Neighborhoods.
# <br><br>
# Assumptions made here are that total population is static (i.e. no new entrants or people moving outside of this subset of neighborhoods), and that there's a 40% chance that people stay in their current neighborhood (which can be interpreted as either not moving or moving very close by) and a known probability of moving from one neighborhood to another (these are defined in the code below), with preference shown for bordering neighborhoods.
# <br><br>
# We will load geo-data and filter to the specified Brooklyn neighborhoods. We will then examine movement between neighborhoods as a Markov Process, iterating until an equilibrium becomes apparent (hint: you should not see any absorbing states in this example), then visualize and interpret the results.

# %% [markdown]
# **Part 1**: Go through the below example, completing the code where marked. (30 points)

# %%
import imageio
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
import time
from IPython.display import HTML


sns.set_style('white')
# filters to apply to the data
county = 'Kings'
hoods  = ['Downtown', 'DUMBO', 'Fort Greene', 'Boerum Hill', 'Clinton Hill']

def get_neighborhoods(file, county=county, neighborhoods=hoods):
    '''
    reads in geopandas file from Zillow, returns geodataframe with specified neighborhoods
    '''
    # read in the geodata file ('file') and consolidate to the 5 selected neighborhoods (listed above)
    
    ny_gdf = gpd.read_file(file)
    ny_gdf = ny_gdf[ny_gdf['County'] == county]
    ny_gdf = ny_gdf[ny_gdf['Name'].isin(hoods)] #First way to filter the Name
    #for i in ny_gdf['Name']:                   #Second way to filter the Name
    #    if i not in neighborhoods:
    #        ny_gdf['Name'].replace(i, 'Nan',inplace =True)
    #ny_gdf = ny_gdf[:5]
    
    
    
    # locate coordinate points to plot neighborhood names
    ny_gdf['coords'] = ny_gdf['geometry'].apply(lambda x: x.representative_point().coords[:])
    ny_gdf['coords'] = [coords[0] for coords in ny_gdf['coords']]
    return ny_gdf

bk_neighborhoods = get_neighborhoods('ZillowNeighborhoodsNY.shp')
bk_neighborhoods = bk_neighborhoods.sort_values('Name').reset_index(drop=True)
bk_neighborhoods
# Out:
#   State County      City          Name RegionID  \
# 0    NY  Kings  New York   Boerum Hill   272994
# 1    NY  Kings  New York  Clinton Hill   270815
# 2    NY  Kings  New York         DUMBO   270841
# 3    NY  Kings  New York      Downtown   270825
# 4    NY  Kings  New York   Fort Greene   273766
#
#                                             geometry  \
# 0  POLYGON ((-73.98682489707035 40.68846655576456...
# 1  POLYGON ((-73.9619257224787 40.69778778197278,...
# 2  POLYGON ((-73.98446723099994 40.70646091900005...
# 3  POLYGON ((-73.98697203810939 40.70105040762233...
# 4  POLYGON ((-73.98230754099966 40.70227250100029...
#
#                                      coords
# 0    (-73.9864896425407, 40.68600290969882)
# 1     (-73.96455445229091, 40.689058350724)
# 2  (-73.99003960915954, 40.703545669500045)
# 3  (-73.98678098579373, 40.693458468711725)
# 4   (-73.97573066517539, 40.69136863239475)

# %% [markdown]
# Above we can see the geodataframe. Now let's plot it:

# %%
bk_neighborhoods.plot(figsize=(8, 6), edgecolor='black', alpha=0.2)

for idx, row in bk_neighborhoods.iterrows():
    plt.annotate(s=row['Name'], xy=row['coords'], color='Black', horizontalalignment='center', size=10)

# %% [markdown]
# Caption: The plot is about the five selected neighbourhoods in NYC Brooklyn .

# %%
plt.annotate?

# %% [markdown]
# Here, we define the likelihoods of moving from one neighborhood to another.
# Use a Dirichlet Distrobution (convenient for generating samples that sum to 1.0) to obtain an initial starting population for the neighborhoods https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.random.dirichlet.html
#
# Dirichlet多项分布的共轭分布；
# 多项：n次n种结果的伯努利实验；
# 共轭：posterior and prior have the same possibility distribution.

# %%
np.random.seed(42)
#####your code here##### # use a dirichlet distribution to create a 1-by-5 matrix of values that sum to 1.0 
diri = np.random.dirichlet((4,4,4,4,4))
data = np.matrix(diri)
initial_vals = zip(list(bk_neighborhoods.Name), np.array(data)[0])

print('Initial allocations:')
print('--------------------')
for i, j in initial_vals:
    print('{:<13s} {:>5.2f}%'.format(i, round(j, 4)*100))
print('--------------------')
print()

move_likelihoods = np.matrix('0.4 0.1 0.1 0.2 0.2; 0.1 0.4 0.1 0.15 0.25; 0.1 0.1 0.4 0.2 0.2;' 
                             + '0.2 0.05 0.15 0.4 0.2; 0.15 0.2 0.05 0.2 0.4')
pd.DataFrame(data=move_likelihoods, index=bk_neighborhoods.Name, columns=bk_neighborhoods.Name) 
# we could use 'tabulate' here, as this is for visualization purposes, but a pd dataframe is 
# often just as clear and has more compatability with python environments
# Out:
# Initial allocations:
# --------------------
# Boerum Hill   21.20%
# Clinton Hill  15.37%
# DUMBO         14.59%
# Downtown      14.59%
# Fort Greene   34.25%
# --------------------
# Name          Boerum Hill  Clinton Hill  DUMBO  Downtown  Fort Greene
# Name
# Boerum Hill          0.40          0.10   0.10      0.20         0.20
# Clinton Hill         0.10          0.40   0.10      0.15         0.25
# DUMBO                0.10          0.10   0.40      0.20         0.20
# Downtown             0.20          0.05   0.15      0.40         0.20
# Fort Greene          0.15          0.20   0.05      0.20         0.40

# %% [markdown]
# Here we will build a Markov process and visualize it in a GIF; this is useful for seeing equilibrium state reached over time. We will then look at the numbers to confirm what the plot is showing us.

# %%
years = 7
pct_by_year = []

def plot_neighborhood_movement(years):

    pct_in_hood = data * np.linalg.matrix_power(move_likelihoods, years)
    #####your code here##### # use the matrix_power function to run a step in the markov process
    bk_neighborhoods['pct_in_hood'] = np.array(pct_in_hood)[0]
    pct_by_year.append(np.array(pct_in_hood)[0])
    vmin, vmax = bk_neighborhoods['pct_in_hood'].min(), bk_neighborhoods['pct_in_hood'].max()

    fig, ax = plt.subplots(figsize=(8,6))
    base = bk_neighborhoods.plot(ax=ax, column='pct_in_hood', edgecolor='grey', 
                                cmap='Blues', vmin=vmin, vmax=vmax, legend=False)

    plt.title('Year:{}'.format(years), size=16)
    
    for idx, row in bk_neighborhoods.iterrows():
        #####your code here##### # put neighborhood names on the plot in red font
        plt.annotate(s=row['Name'],color = 'Red',xy=row['coords'],horizontalalignment='center', size=10)
    
    #To transform the plot into string data
    # If we haven't already shown or saved the plot, then we need to 
    # draw the figure first...
    fig.canvas.draw()
    # Now we can save it to a numpy array
    image = np.frombuffer(fig.canvas.tostring_rgb(), dtype='uint8')# np.frombuffer()创建一个和a共享内存的NumPy数组
    image = image.reshape(fig.canvas.get_width_height()[::-1] + (3,))
    #we don't want to plot single graph
    plt.close(fig)
    return image

kwargs_write = {'fps':1.0, 'quantizer':'nq'}
imageio.mimsave('neighborhood_movement.gif', [plot_neighborhood_movement(year) for year in range(years)], fps=1)
#imageio.mimsave()get all the pngs and merge into one gif 
HTML('<img src="neighborhood_movement.gif">')
# Out:
# <img src="neighborhood_movement.gif">

# %%
# To download the GIF

# %% [markdown]
# Caption: The gif plot shows that the population in each area through 7 years. What worths mentioned is that after 7 years the population of an area will be stationary.

# %%
pd.DataFrame(data=np.matrix(pct_by_year), columns=bk_neighborhoods.Name, 
             index=['Year {}'.format(i) for i in range(len(np.matrix(pct_by_year)))]).style.format("{:.1%}")
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_dd91654a_e485_11e8_923f_0e46826d5f26" >
# <thead>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="col_heading level0 col0" >Boerum Hill</th>
#         <th class="col_heading level0 col1" >Clinton Hill</th>
#         <th class="col_heading level0 col2" >DUMBO</th>
#         <th class="col_heading level0 col3" >Downtown</th>
#         <th class="col_heading level0 col4" >Fort Greene</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_dd91654a_e485_11e8_923f_0e46826d5f26level0_row0" class="row_heading level0 row0" >Year 0</th>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row0_col0" class="data row0 col0" >21.2%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row0_col1" class="data row0 col1" >15.4%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row0_col2" class="data row0 col2" >14.6%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row0_col3" class="data row0 col3" >14.6%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row0_col4" class="data row0 col4" >34.3%</td>
#     </tr>    <tr>
#         <th id="T_dd91654a_e485_11e8_923f_0e46826d5f26level0_row1" class="row_heading level0 row1" >Year 1</th>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row1_col0" class="data row1 col0" >19.5%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row1_col1" class="data row1 col1" >17.3%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row1_col2" class="data row1 col2" >13.4%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row1_col3" class="data row1 col3" >22.1%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row1_col4" class="data row1 col4" >27.6%</td>
#     </tr>    <tr>
#         <th id="T_dd91654a_e485_11e8_923f_0e46826d5f26level0_row2" class="row_heading level0 row2" >Year 2</th>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row2_col0" class="data row2 col0" >19.5%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row2_col1" class="data row2 col1" >16.8%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row2_col2" class="data row2 col2" >13.7%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row2_col3" class="data row2 col3" >23.6%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row2_col4" class="data row2 col4" >26.4%</td>
#     </tr>    <tr>
#         <th id="T_dd91654a_e485_11e8_923f_0e46826d5f26level0_row3" class="row_heading level0 row3" >Year 3</th>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row3_col0" class="data row3 col0" >19.5%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row3_col1" class="data row3 col1" >16.5%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row3_col2" class="data row3 col2" >14.0%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row3_col3" class="data row3 col3" >23.9%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row3_col4" class="data row3 col4" >26.1%</td>
#     </tr>    <tr>
#         <th id="T_dd91654a_e485_11e8_923f_0e46826d5f26level0_row4" class="row_heading level0 row4" >Year 4</th>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row4_col0" class="data row4 col0" >19.5%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row4_col1" class="data row4 col1" >16.4%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row4_col2" class="data row4 col2" >14.1%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row4_col3" class="data row4 col3" >23.9%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row4_col4" class="data row4 col4" >26.0%</td>
#     </tr>    <tr>
#         <th id="T_dd91654a_e485_11e8_923f_0e46826d5f26level0_row5" class="row_heading level0 row5" >Year 5</th>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row5_col0" class="data row5 col0" >19.6%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row5_col1" class="data row5 col1" >16.3%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row5_col2" class="data row5 col2" >14.1%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row5_col3" class="data row5 col3" >24.0%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row5_col4" class="data row5 col4" >26.0%</td>
#     </tr>    <tr>
#         <th id="T_dd91654a_e485_11e8_923f_0e46826d5f26level0_row6" class="row_heading level0 row6" >Year 6</th>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row6_col0" class="data row6 col0" >19.6%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row6_col1" class="data row6 col1" >16.3%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row6_col2" class="data row6 col2" >14.1%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row6_col3" class="data row6 col3" >24.0%</td>
#         <td id="T_dd91654a_e485_11e8_923f_0e46826d5f26row6_col4" class="data row6 col4" >26.0%</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# **Part 2**: Interpret the results - what trends do we notice towards the end of the GIF? Why might this be? What would we expect if we ran this over 100 iterations (feel free to try this)? (10 points)

# %%
years = 100
pct_by_year = []

def plot_neighborhood_movement(years):

    pct_in_hood = data * np.linalg.matrix_power(move_likelihoods, years)
    #####your code here##### # use the matrix_power function to run a step in the markov process
    
    pct_by_year.append(np.array(pct_in_hood)[0])
    
[plot_neighborhood_movement(year) for year in range(years)]
pd.DataFrame(data=np.matrix(pct_by_year), columns=bk_neighborhoods.Name, index=['Year {}'.format(i) for i in range(len(np.matrix(pct_by_year)))]).style.format("{:.1%}")
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_de982fe6_e485_11e8_923f_0e46826d5f26" >
# <thead>    <tr>
#         <th class="index_name level0" >Name</th>
#         <th class="col_heading level0 col0" >Boerum Hill</th>
#         <th class="col_heading level0 col1" >Clinton Hill</th>
#         <th class="col_heading level0 col2" >DUMBO</th>
#         <th class="col_heading level0 col3" >Downtown</th>
#         <th class="col_heading level0 col4" >Fort Greene</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row0" class="row_heading level0 row0" >Year 0</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row0_col0" class="data row0 col0" >21.2%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row0_col1" class="data row0 col1" >15.4%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row0_col2" class="data row0 col2" >14.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row0_col3" class="data row0 col3" >14.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row0_col4" class="data row0 col4" >34.3%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row1" class="row_heading level0 row1" >Year 1</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row1_col0" class="data row1 col0" >19.5%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row1_col1" class="data row1 col1" >17.3%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row1_col2" class="data row1 col2" >13.4%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row1_col3" class="data row1 col3" >22.1%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row1_col4" class="data row1 col4" >27.6%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row2" class="row_heading level0 row2" >Year 2</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row2_col0" class="data row2 col0" >19.5%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row2_col1" class="data row2 col1" >16.8%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row2_col2" class="data row2 col2" >13.7%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row2_col3" class="data row2 col3" >23.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row2_col4" class="data row2 col4" >26.4%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row3" class="row_heading level0 row3" >Year 3</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row3_col0" class="data row3 col0" >19.5%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row3_col1" class="data row3 col1" >16.5%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row3_col2" class="data row3 col2" >14.0%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row3_col3" class="data row3 col3" >23.9%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row3_col4" class="data row3 col4" >26.1%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row4" class="row_heading level0 row4" >Year 4</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row4_col0" class="data row4 col0" >19.5%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row4_col1" class="data row4 col1" >16.4%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row4_col2" class="data row4 col2" >14.1%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row4_col3" class="data row4 col3" >23.9%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row4_col4" class="data row4 col4" >26.0%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row5" class="row_heading level0 row5" >Year 5</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row5_col0" class="data row5 col0" >19.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row5_col1" class="data row5 col1" >16.3%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row5_col2" class="data row5 col2" >14.1%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row5_col3" class="data row5 col3" >24.0%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row5_col4" class="data row5 col4" >26.0%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row6" class="row_heading level0 row6" >Year 6</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row6_col0" class="data row6 col0" >19.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row6_col1" class="data row6 col1" >16.3%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row6_col2" class="data row6 col2" >14.1%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row6_col3" class="data row6 col3" >24.0%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row6_col4" class="data row6 col4" >26.0%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row7" class="row_heading level0 row7" >Year 7</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row7_col0" class="data row7 col0" >19.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row7_col1" class="data row7 col1" >16.3%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row7_col2" class="data row7 col2" >14.1%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row7_col3" class="data row7 col3" >24.0%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row7_col4" class="data row7 col4" >26.0%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row8" class="row_heading level0 row8" >Year 8</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row8_col0" class="data row8 col0" >19.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row8_col1" class="data row8 col1" >16.3%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row8_col2" class="data row8 col2" >14.1%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row8_col3" class="data row8 col3" >24.0%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row8_col4" class="data row8 col4" >26.0%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row9" class="row_heading level0 row9" >Year 9</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row9_col0" class="data row9 col0" >19.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row9_col1" class="data row9 col1" >16.3%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row9_col2" class="data row9 col2" >14.1%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row9_col3" class="data row9 col3" >24.0%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row9_col4" class="data row9 col4" >26.0%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row10" class="row_heading level0 row10" >Year 10</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row10_col0" class="data row10 col0" >19.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row10_col1" class="data row10 col1" >16.3%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row10_col2" class="data row10 col2" >14.1%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row10_col3" class="data row10 col3" >24.0%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row10_col4" class="data row10 col4" >26.0%</td>
#     </tr>    <tr>
#         <th id="T_de982fe6_e485_11e8_923f_0e46826d5f26level0_row11" class="row_heading level0 row11" >Year 11</th>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row11_col0" class="data row11 col0" >19.6%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row11_col1" class="data row11 col1" >16.3%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26row11_col2" class="data row11 col2" >14.1%</td>
#         <td id="T_de982fe6_e485_11e8_923f_0e46826d5f26

# %% [markdown]
# ### Answer:
# 1. In the later years the distributions of neighehoods will receive an equilibrium and keep the same. $Year_{\mathrm{t-1}} = Year_{\mathrm{t-1}}*P = Year_{\mathrm{t}}$
# 2. No matter what the first year distributions are, the final equilibrium will keep the same as long as the possibility table(possibility that people move from one neighbourhood to another) keeps the same.

# %% [markdown]
# This is some pretty cool stuff! If you had enough data, you could theoretically do this for all of NYC (you'd additionally have to factor in people moving into and out of the city, but that's not too hard. Further, you might change the percentages over time (e.g. when the L-train shuts down, you may want to lower the % of people moving to Williamsburg in your model - all sorts of cool things you can do!).

# %% [markdown]
# ### Problem 2 - Time Series (40 points)

# %% [markdown]
# This dataset looks at measurements of electric power consumption in one household with a one-minute sampling rate over a period of almost 4 years; the data is initially messy, and will take a lot of cleaning. You will find that there is some correlation between the data (i.e. what we know about the current state can tell us something about the future state), and you will then construct an Autoregressive Model to predict future values.
#
# Source: https://archive.ics.uci.edu/ml/datasets/individual+household+electric+power+consumption
#
# Variable Descriptions:
# 1. date: Date in format dd/mm/yyyy <br>
# 2. time: time in format hh:mm:ss <br>
# 3. global_active_power: household global minute-averaged active power (in kilowatt) <br>
# 4. global_reactive_power: household global minute-averaged reactive power (in kilowatt) <br>

# %%
from pandas.plotting import lag_plot
from pandas.plotting import autocorrelation_plot
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.ar_model import AR

sns.set_style('darkgrid')
# %matplotlib inline

cols = ['Date', 'Global_active_power', 'Global_reactive_power']

# %%
test = pd.read_csv('household_power_consumption.txt', sep=';',nrows=10)
sample = test[::2000]
sample.head()
# Out:
#          Date      Time  Global_active_power  Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00                4.216                  0.418   234.84
#
#    Global_intensity  Sub_metering_1  Sub_metering_2  Sub_metering_3
# 0              18.4             0.0             1.0            17.0

# %% [markdown]
# **Part 1**: Read in the data. It is in a .txt file, but you can read it in with 'pd.read_csv()' - you may want to consider the  'sep', 'parse_dates', 'usecols', 'infer_datetime_format', 'keep_default_na', 'skip_blank_lines', 'skiprows', and 'dtype' arguements in the function. You also may want to use the 'nrows' arguement or use a limited version of the dataset as you adjust these, as it is a large one. Finally, you may need to read in the dataset more than once if you want to use the 'dtype' arguement to create floating-points (hint: the 'skiprows' arguement may need a +1 to work as expected). (15 points)

# %%
cols = ['Date', 'Global_active_power', 'Global_reactive_power']

pwr_consumption = pd.read_csv('household_power_consumption.txt', sep=';',usecols=cols,
                              skip_blank_lines=True,
                              date_parser=lambda dates: pandas.datetime(column='Date'))#####your code here#####)
#One of parameter to choose sample from read_csv: skiprows=[2*x+1 for x in range(100000)],
#####your code here##### # group the newly-cleaned data by date, using the .sum() function to aggregate
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/ADS/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.read_csv?

# %%
#pwr_consumption.replace('?',None,inplace=True) # have to replace to None, if I want to drop nan, otherwise the Nan is a string
#pwr_consumption.dropna(inplace=True)
pwr_consumption['Global_active_power'] = pd.to_numeric(pwr_consumption['Global_active_power'],errors='coerce')# errors means when there is other uncertain content, just transfer it into 0
pwr_consumption['Global_reactive_power'] = pd.to_numeric(pwr_consumption['Global_reactive_power'],errors='coerce')

# %%
pwr_consumption.head()
# Out:
#          Date  Global_active_power  Global_reactive_power
# 0  16/12/2006                4.216                  0.418
# 1  16/12/2006                5.360                  0.436
# 2  16/12/2006                5.374                  0.498
# 3  16/12/2006                5.388                  0.502
# 4  16/12/2006                3.666                  0.528

# %%
#pwr_consumption.Global_reactive_power.astype(float)
pwr_byday = pwr_consumption.groupby(pwr_consumption['Date']).sum()
pwr_byday['date']=pd.to_datetime(pwr_byday.index,errors='coerce')
pwr_byday.index=pd.to_datetime(pwr_byday.index,errors='coerce')
pwr_byday.sort_values('date',inplace=True)
pwr_byday.dropna(inplace=True)
pwr_byday.head()
# Out:
#             Global_active_power  Global_reactive_power       date
# Date
# 2006-12-16             1209.176                 34.922 2006-12-16
# 2006-12-17             3390.460                226.006 2006-12-17
# 2006-12-18             2203.826                161.792 2006-12-18
# 2006-12-19             1666.194                150.942 2006-12-19
# 2006-12-20             2225.748                160.998 2006-12-20

# %%
type(pwr_byday.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# **Part 2**: Plot the data. Use the lag_plot() function to examine the correlation. Describe your findings. (10 points)

# %%
glb_active_pwr   = pwr_byday['Global_active_power']#####your code here#####
glb_reactive_pwr = pwr_byday['Global_reactive_power']#####your code here#####

def time_series_plotting(func, series1, series2):
    """
    takes time series data and plots, based on a give function
    """
    fig, ax = plt.subplots(2, figsize=(15,6))

    plt.subplot(121)
    #####your code here#####
    fig = func(series1)
    plt.title('{} {}'.format(series1.name, func.__name__).replace('_', ' ').title(),fontsize=16)

    plt.subplot(122)
    #####your code here#####
    ax = func(series2)
    plt.title('{} {}'.format(series2.name, func.__name__).replace('_', ' ').title(),fontsize=16)

    plt.tight_layout()
    plt.show()

time_series_plotting(plt.plot, glb_active_pwr, glb_reactive_pwr)
time_series_plotting(lag_plot, glb_active_pwr, glb_reactive_pwr)

# %% [markdown]
# (your description here)From the Lag Plot, we can see a large ball of observations along a diagonal line of the plot.There is a autocorrelation both in Global Active Power and Global Reactive Power. According to the first two plot, the corvariance of two variebles are finite and the model should be stationary which means the $|\rho|$ may be less than 1.

# %% [markdown]
# **Part 3**: Fit an autoregressive model to the data, and use it to make predictions over the next 30 days of useage (defined by creating a test set from the last 30 days of available data). Describe your findings. (15 points)

# %%
def fit_AR1(series):
    vals = series.values
    train, test = vals[1:len(vals)-30], vals[len(vals)-30:]
    
    model = AR(train)#####your code here#####
    model_fit = model.fit()#####your code here#####
    print(series.name)
    print('Lag: %s' % model_fit.k_ar)
    predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False)
    #####your code here#####
    for i in range(len(predictions)):
        error = mean_squared_error(test, predictions)#####your code here#####
    print('Test_Active MSE: %.3f' % error)
    return test, predictions

t1, p1 = fit_AR1(glb_active_pwr)
print()
t2, p2 = fit_AR1(glb_reactive_pwr)

fig, ax = plt.subplots(2, figsize=(16,6))

plt.subplot(121)
plt.plot(t1, label='test_data')
plt.plot(p1, color='red', label='AR_predictions')
plt.title('Global Active Power')
plt.legend()

plt.subplot(122)
plt.plot(t2, label='test_data')
plt.plot(p2, color='red', label='AR_predictions')
plt.title('Global Reactive Power')
plt.legend()

plt.show()
# Out:
# Global_active_power
# Lag: 23
# Test_Active MSE: 163223.941
#
# Global_reactive_power
# Lag: 23
# Test_Active MSE: 2563.357

# %% [markdown]
# Caption: The prediction of AR(1) is kind of a good fit for 'Global Active Power', not good for Global_Reactive_power variable. The AR_prediction fluctuate a little bit at first and have the same trend with the test data, especially in the first 10 days. However with the prediction period gets longer, the fluctuation becomes stable the prediction gets weeker, especially in the second 15 days.

# %% [markdown]
# ### Problem 3 - Return on University Education (20 points)

# %% [markdown]
# Please read the following article: https://promarket.org/learning-university-pay-off/
#
# Consider Judea Pearl's idea of the ladder of causality that was discussed in class.  Describe whether or not the study described in the article meets the standard of (a) association; (b) intervention; and (c) counterfactual.

# %% [markdown]
# **(a)** In the passage, the author did find the association between the number of courses students took and the employment rate in the largest company. However, whether the two variable are representative of the amount of knowledge students learn and the quality of jobs after graduation is remained to doubt.
#
# The less courses to take cannot represent the less knowlege they learn. Maybe the syllabus of each courses was added more requirment and depth in study.
#
# The wages after graduation is a good way to evaluation the quality of jobs. The employing rate in one largest company may not be generalized because the company itself may change the business strategy to hire more employees in other major for Fintech or other services.

# %% [markdown]
# **(b)** Suppose the association in author's hypothesis does exist. The author does exclude the intervention of admission requirement. But she should also measure the IQ  or other test score after students' 4 years study to make sure the ability of students does not increase dramatically because they have less courses and more time to develop by themselves.
#
# She should look at the total employ rate. Whether the rate decreases because of the economy recession or the change of social labor demand in other major like computer science.

# %% [markdown]
# **(c)** She hasn't measure employment rate of other colleges which are similar to Los Andes University except the courses reform. If her hypothesis causation does exist, their rates should keep the same or increased.
